# %% [markdown]
# ### Dependencies

# %%
import os
import shutil
import pickle
import numpy as np
import json
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon as MatplotlibPolygon
from shapely import wkt
import shapely
import shapely.geometry as sg
from shapely.geometry import Polygon, LineString, Point, MultiPoint
import networkx as nx
import geopandas as gp
from shapely.ops import nearest_points 
from typing import Dict, List, Tuple, Union
from sklearn import preprocessing

# from Plan import Plan
from RoomColours import roomColours
from MarkovChainClass import *
from read_historic_data import *

# %% [markdown]
# ### Load SDDS plan data as dictionary

# %%
def load_dict_from_file(file_path):
    """ dataset composed in read_plans_csv.ipynb"""
    with open(file_path, 'rb') as file:
        data_dict = pickle.load(file)
    return data_dict

plans = load_dict_from_file('Plans.pickle')
plan_ids = load_dict_from_file('plan_ids.pickle')
apartment_ids = load_dict_from_file('apartment_ids.pickle')

# %% [markdown]
# ### Perform MC simulation on decomposition graph

# %%
""" Monte Carlo Simulation of decomposition graph used to label floor plan pre-evacuation times"""

pre_evac_time_per_start = []
behaviour_class = behaviour_in_fire_markov_chain(10000, node_attributes = optimal_node_attributes)

for i in Start_nodes:
    total_time_i = round(behaviour_class.simulate_markov_chain(i, 10000), 2)
    pre_evac_time_per_start.append(total_time_i)


print(pre_evac_time_per_start)
# Out:
# [426.68, 365.52, 369.76, 144.92]

# %% [markdown]
# ### Create class to analyse plan geometry and adjacencies in terms of fire safety

# %%
class Plan:
    """ Class used to find plan rooms, adjacencies (with / without door) , evacuation times (Tp, Te) and create Graph (G = {N,E}) for predicting risk in a given floor plan"""
    def __init__(
            self, 
            Plan_id: int, 
            Apartment_id: str, 
            plans: dict,
            mrkv_chain_behaviours: behaviour_in_fire_markov_chain,
            room_of_origin_weights: dict
    ):
        
        ## identification of plan
        self.plans = plans
        self.plan_id = Plan_id
        self.apartment_id = Apartment_id

        ## rooms / nodes
        self.rooms = self.__get_rooms()
        self.room_attributes = self.__get_room_attributes()
        self.doors, self.door_widths, self.entrance_door  = self.__get_doors()

        ## walls
        self.walls = self.__get_walls()

        ## distances between rooms and adjacency lists
        self.connections_without_doors = self.__get_room_room_connections()
        self.connections_with_doors, self.door_widths = self.__get_room_door_room_connections()
        self.entrance_connection, self.entrance_door_centre = self.__get_entrance_connection()
        self.edges_with_weights, self.edge_door_widths = self.__get_room_adjacencies()
        self.edge_midpoints = self.__get_edge_midpoints()
        self.edge_attributes = self.__get_edge_attributes()

        ## get centres of nodes
        self.room_centers = self.__get_room_centres()

        ## markov chain fire emergency behaviour
        self.mrk_chain = mrkv_chain_behaviours

        ## room of origin likelihood
        self.room_of_origin_weights = room_of_origin_weights
        
        ## graph
        self.graph = self.__make_graph()

    def show_plan_apartment(self) -> None:
        """ Displays the plan of the one apartment specified in class initiation """

        #    Extract plan ID and apartment ID
        plan_id = self.plan_id
        apartment_id = self.apartment_id

        # Load geometry from plans
        geo = shapely.wkt.loads(self.plans[plan_id][apartment_id]['geometries_dict'])
        
        # Plot the geometry
        plt.figure()
        p = gp.GeoSeries(geo)

        p.plot(color=self.__give_colours())


        
        # Set title
        plt.suptitle('Plan: ' + str(plan_id) + ', ' + 'apartment: ' + apartment_id)
        
        # Show plot
        plt.show()

    def show_plan(self) -> None:
        """ Displays the plan of the whole floor in which the plan is in"""
        
        # Extract plan ID
        plan_id = self.plan_id

        # Initialize lists for geometry and colors
        _geo = []
        colours = []

        # Iterate over apartment IDs for the given plan
        for apartment_id in apartment_ids[plan_id]:
            # Create a Plan object for the current apartment
            plan = Plan(plan_id, apartment_id, plans, self.mrk_chain, self.room_of_origin_weights)
            
            # Append colors from the current apartment to the colors list
            colours += plan.__give_colours()
            
            # Append geometry from the current apartment to the _geo list
            _geo.append(shapely.wkt.loads(self.plans[plan_id][apartment_id]['geometries_dict']))

        # Flatten the list of geometries_dict
        geo = [polygon for row in _geo for polygon in row]

        # Plot the geometries_dict
        p = gp.GeoSeries(geo)
        p.plot(color=colours)
        
        # Set title
        plt.suptitle('Plan: ' + str(plan_id))
        
        # Show plot
        plt.show()

    def show_graph(self) -> None:
        """Displays the graph representation of the floor plan"""

        G = self.graph
        pos = self.room_centers
        edge_labels = {(node1, node2): str(distance) for node1, node2, distance in self.edges_with_weights}

        plt.figure(figsize=(10, 10))  # Initiate graph figure

        # Draw nodes
        node_colors = [G.nodes[node]['colour'] for node in G.nodes()]
        node_sizes = [((G.nodes[node]['room_area'] + 10) * 200) for node in G.nodes()]
        nx.draw(G, 
                pos=pos, 
                with_labels=False,
                node_color=node_colors, 
                node_size=node_sizes, 
                alpha=0.3, 
                linewidths=5
            )

        # Draw edges
        nx.draw_networkx_edges(G, 
                            pos, 
                            width=1, 
                            edge_color='#AAAE7F'
                        )

        # Draw node labels
        node_labels = {
            node: (f"{G.nodes[node]['node_index']}: {G.nodes[node]['room_type']}\n"
                f"exit_dis: {G.nodes[node]['distance_to_exit']}\n"
                f"area: {G.nodes[node]['room_area']}\n"
                f"Tp: {G.nodes[node]['time_pre_evac']}\n"
                f"Te: {G.nodes[node]['time_evac']}\n"
                f"b_c: {round(G.nodes[node]['betweenness_centrality'],2)}\n"
                f"c_c: {round(G.nodes[node]['closeness_centrality'],2)}")
            for node in G.nodes()
        }
        nx.draw_networkx_labels(G, 
                                pos=pos, 
                                labels=node_labels, 
                                font_size=9, 
                                font_weight='normal',
                                horizontalalignment='center'
                            )

        # Draw edge labels
        nx.draw_networkx_edge_labels(G, 
                                    pos, 
                                    edge_labels=edge_labels, 
                                    font_weight='bold', 
                                    alpha=0.35
                                )

        plt.show()  # Show graph

    def __give_colours(self) -> List[str]:
        """ Returns the list of room colours for all rooms in the plan, according to RoomColours.py"""

        # Extract plan ID and apartment ID
        plan_id = self.plan_id
        apartment_id = self.apartment_id

        # Get subtypes for the given plan and apartment
        subtypes = self.plans[plan_id][apartment_id]['sub_type_dict']

        # Map subtypes to colors
        colours = [roomColours[x] for x in subtypes]

        return colours

    def __get_rooms(self) -> List[Polygon]:
        """ Returns all rooms in the plans as List of polygons """

        # Extract plan ID and apartment ID
        plan_id = self.plan_id
        apartment_id = self.apartment_id

        # Fetch geometries_dict and types of apartment components from self.plans dictionary
        component_geometry = self.plans[plan_id][apartment_id]['geometries_dict']
        types = self.plans[plan_id][apartment_id]['types_dict']
        sub_types = self.plans[plan_id][apartment_id]['sub_type_dict']

        # Extract room shapes excluding shafts
        rooms = [component_geometry[i] for i, x in enumerate(types) if types[i] == 'area' and sub_types[i] != 'SHAFT']
        
        # Convert WKT (Well-Known Text) format to Shapely geometries_dict for visualization and analysis
        rooms = [shapely.wkt.loads(room) for room in rooms]
        
        return rooms
    
    def __get_room_attributes(self) -> Dict[int, Dict]:
        """ Make room attributes dictionary => {node_id : {attributes}, node_id: {attributes}} """

        # Extract plan ID and apartment ID
        plan_id = self.plan_id
        apartment_id = self.apartment_id

        # Extract component information from the floor plan
        types = self.plans[plan_id][apartment_id]['types_dict']
        sub_types = self.plans[plan_id][apartment_id]['sub_type_dict']
        area_ids = self.plans[plan_id][apartment_id]['area_ids_dict']
        max_distances_to_entrance = self.plans[plan_id][apartment_id]['distance_to_exit_dict']

        # Extract room types excluding shafts
        room_types = [sub_types[i] for i, x in enumerate(types) if types[i] == 'area' and sub_types[i] != 'SHAFT']
        room_indices = list(range(len(room_types)))

        # Extract room area IDs
        room_area_ids = [area_ids[i] for i, x in enumerate(sub_types) if x != 'SHAFT']

        # Extract room areas
        room_areas = [round(room.area, 2) for room in self.rooms]

        # Initialize room attributes dictionary
        room_attributes = {}

        # Populate room attributes
        for i, idx in enumerate(room_indices):
            room_attributes[idx] = {
                'room_type': room_types[i],
                'room_area_id': room_area_ids[i],
                'distance_to_exit': max_distances_to_entrance[i],
                'room_area': room_areas[i]
            }

        # Add entrance door properties
        entrance_door_area_ids = [area_ids[i] for i, x in enumerate(sub_types) if x == 'ENTRANCE_DOOR']
        entrance_door_idx = room_indices[-1] + 1
        room_attributes[entrance_door_idx] = {
            'room_type': 'ENTRANCE_DOOR',
            'room_area_id': entrance_door_area_ids[0],
            'distance_to_exit': 0,
            'room_area': 0
        }

        return room_attributes

    def __get_room_centres(self) -> Dict[int, Tuple[float, float]]:
        """ Returns a dictionary of key : value as node_id: centroid"""
        
        # Extract rooms and entrance door
        rooms = self.rooms
        entrance_door_centre = self.entrance_door_centre
        
        # Initialize list of room indices
        room_indices = list(range(len(rooms)))

        # Add index for the entrance door
        room_indices.append(len(rooms))

        # Compute centroids of rooms and entrance door
        centroids_pts = [shape.centroid for shape in rooms]
        centroids_pts.append(entrance_door_centre)

        # Create dictionary mapping indices to centroid coordinates
        centroids_coords_dict = {
            i: (round(point.x, 2), round(point.y, 2)) 
            for i, point in zip(room_indices, centroids_pts)
        }
        
        return centroids_coords_dict

    def __get_doors(self) -> Tuple[List[Polygon], Dict, Polygon]:
        """ Returns a list of all doors, including the entrance door, as a list of polygons"""

        # Extract plan ID and apartment ID   
        plan_id = self.plan_id
        apartment_id = self.apartment_id

        # Extract component geometries_dict and subtypes
        components = self.plans[plan_id][apartment_id]['geometries_dict']
        sub_type_dict = self.plans[plan_id][apartment_id]['sub_type_dict']

        # Extract door geometries_dict and entrance door geometry
        doors = [components[i] for i, subtype in enumerate(sub_type_dict) if subtype in ['DOOR', 'ENTRANCE_DOOR']]
        entrance_door = [components[i] for i, x in enumerate(sub_type_dict) if sub_type_dict[i] == 'ENTRANCE_DOOR' ]

        # Convert geometries_dict from WKT to Shapely polygons
        doors = shapely.wkt.loads(doors)
        entrance_door = shapely.wkt.loads(entrance_door)[0]

        def get_door_widths(doors):
            """ Returns a list of door widths for each apartment, same indexing as self.doors"""

            ## initialise door widths list
            door_widths = []


            for door in doors:
                # Get the bounding box
                minx, miny, maxx, maxy = door.bounds

                # Calculate width and length
                width = maxx - minx
                length = maxy - miny

                # Return the smallest of the two
                door_width = max(width, length)
                door_widths.append(door_width)

            ## normalise door widths, so that connections without doors have weight of 1.0.
            def normalize_list(values, min_value=0.75, max_value=0.1):
                min_val = min(values)
                max_val = max(values)

                normalized_values = [0.1 for v in values]

                for i, v in enumerate(values):
                    if (max_val - min_val) == 0:
                        normalized_values[i] = 0.05
                    else:
                        normalized_values[i] = round( ((v - min_val) / (max_val - min_val) * (max_value - min_value) + min_value), 2) 
                        
                return normalized_values
            
            if len(door_widths) == 1:
                width = door_widths[0]
                if width > 0.75:
                    normalised_door_widths = 0.0
                else:
                    normalised_door_widths = 0.75 / width
            normalised_door_widths = normalize_list(door_widths)

            return normalised_door_widths
        
        door_widths = get_door_widths(doors)
        door_widths = {key: value for key, value in zip([i for i in range(len(doors))], door_widths)}

        return doors, door_widths, entrance_door
    
    def __get_walls(self) -> List[Polygon]:
        """ Returns all wall shapes in the plan as a list of polygons"""

        # Extract plan ID and apartment ID
        plan_id = self.plan_id
        apartment_id = self.apartment_id

        # Extract component geometries_dict and subtypes
        components = self.plans[plan_id][apartment_id]['geometries_dict']
        component_subtypes = self.plans[plan_id][apartment_id]['sub_type_dict']

        # Extract wall geometries_dict
        walls = [components[i] for i, subtype in enumerate(component_subtypes) if subtype == 'WALL']

        # Convert geometries_dict from WKT to Shapely polygons
        walls = [shapely.wkt.loads(wall) for wall in walls]

        return walls

    def __get_room_room_connections(self) -> Dict[Tuple[int, int], float]:
        connection_distances = {}
        connections_set = set()  # Adjacency matrix of rooms

        # Iterate over rooms
        for from_index, from_room in enumerate(self.rooms):
            # Check connections to neighboring rooms without doors (open plan)
            for to_index, to_room in enumerate(self.rooms):
                if from_index == to_index:
                    continue

                # Find nearest points between rooms
                roomToRoom_nearestPts = nearest_points(from_room, to_room)
                roomToRoom_distance = round(roomToRoom_nearestPts[0].distance(roomToRoom_nearestPts[1]), 2)

                if roomToRoom_distance < 0.07:
                    # Sort connection, turn to tuple and add to set to prevent duplicate connections
                    connection = tuple(sorted([from_index, to_index]))
                    connections_set.add(connection)

                    # Calculate mean connection distance (edge weight) and add to connection_distances
                    pt_current_centre = from_room.centroid
                    pt_neighbour_centre = to_room.centroid
                    pt_connection = Point((pt_current_centre.x + pt_neighbour_centre.x) / 2,
                                        (pt_neighbour_centre.y + pt_current_centre.y) / 2)
                    line_connection_walk = LineString([pt_current_centre, pt_connection, pt_neighbour_centre])
                    length_connection_walk = line_connection_walk.length
                    connection_distances[connection] = round(length_connection_walk, 2)

        return connection_distances
    
    def __get_room_door_room_connections(self) -> Tuple[Dict, Dict]:
        rooms = self.rooms
        doors = self.doors
        connections_set = set()
        connection_distances = {}
        door_widths = {}

        for door_index, door in enumerate(doors):
            # make a connection (pair of rooms) for every door
            connection = []
            for room_index, room in enumerate(rooms):
                doorToRoom_nearestPts = nearest_points(door, room)
                doorToRoom_distance = round(doorToRoom_nearestPts[0].distance(doorToRoom_nearestPts[1]), 2)
                if doorToRoom_distance == 0.0:
                    connection.append(room_index)
            # turn list into tuple and add to set to prevent adding duplicates
            if len(connection) <= 1:
                continue

            # sort connection, turn to tuple and add to set to prevent duplicate connections
            connection.sort()
            connection = tuple(connection)
            connections_set.add(connection)

            ## add door index to dictionary for adding it as an edge attribute in self.make_graph()
            door_widths[connection] = self.door_widths[door_index]

            # calculate and add mean connection distance (edge weight) to connection distances
            from_room = rooms[connection[0]]
            to_room = rooms[connection[1]]

            pt_current_centre = from_room.centroid
            pt_neighbour_centre = to_room.centroid
            pt_door_centre = door.centroid
            line_connection_walk = LineString([pt_current_centre, pt_door_centre, pt_neighbour_centre])
            length_connection_walk = line_connection_walk.length
            connection_distances[connection] = round(length_connection_walk, 2)

        return connection_distances, door_widths

    def __get_entrance_connection(self) -> Tuple[Dict, Tuple[float, float]]:
        # Extract necessary attributes
        entrance_door = self.entrance_door
        entrance_door_centre = entrance_door.centroid
        rooms = self.rooms
        entrance_door_node_id = len(rooms)
        
        # Initialize variables
        connections_set = set()
        connection_dict = {}

        # Iterate over each room to compute connections with the entrance door
        for i, room in enumerate(rooms):
            # Compute distance between nearest points of the door and the current room
            e_door_nearest_pts = nearest_points(entrance_door, room)
            distance = round(e_door_nearest_pts[0].distance(e_door_nearest_pts[1]), 2)

            # If the distance is 0, the door is adjacent to the room
            if distance == 0.0:
                # Create a connection between the entrance door and the room
                connection = [entrance_door_node_id, i]
                
                # Compute connection weight (distance between the centre of the door and the centre of the room)
                connection_distance = self.room_attributes[i]['distance_to_exit']
                if not 0 <= connection_distance <= 100:
                    connection_distance = round(entrance_door.centroid.distance(room.centroid), 2)
                # connection_distance = round(entrance_door_centre.distance(room.centroid), 2)
                
                # Sort connection and convert to tuple
                connection.sort()
                connection = tuple(connection)
                
                # Add connection to the set to prevent duplicates
                connections_set.add(connection)
                
                # Convert the set to a list and extract the connection tuple
                connections = [tup for tup in connections_set]
                connections = connections[0]
                
                # Add connection and its distance to the connection dictionary
                connection_dict[connections] = connection_distance
                    
        return connection_dict, entrance_door_centre

    def __make_graph(self) -> nx.Graph:
        """ Constructs a nx.Graph component from Nodes, Edges, Node attributes and Edge Attributes"""

        # Initialize an empty graph
        G = nx.Graph()

        # Add edges with weights and edge attributes
        G.add_weighted_edges_from(self.edges_with_weights)
        nx.set_edge_attributes(G, self.edge_attributes, 'attributes')

        # Get shortest paths to exit
        shortest_paths = self.__get_shortest_paths_to_exit(G)

        Tp, Te = self.__get_exit_times()

        # Add nodes and attributes
        for i in G.nodes:
            # Extract room attributes
            room_type = self.room_attributes[i]['room_type']
            distance_to_exit = self.room_attributes[i]['distance_to_exit']
            node_area = self.room_attributes[i]['room_area']
            time_pre_evac = Tp[i]
            time_evac = Te[i]
 
            # Correct distance to exit if invalid
            if not 0 <= distance_to_exit <= 100:
                distance_to_exit = shortest_paths[i]

            if time_evac < 0.01:
                time_evac = round(distance_to_exit / 0.7, 2)

            # Get node color
            node_color = roomColours[room_type]

            # Add node to graph
            G.add_node(
                i, 
                colour=node_color, 
                room_type=room_type, 
                distance_to_exit=distance_to_exit, 
                node_index=i, 
                room_area=node_area,
                time_pre_evac= time_pre_evac,
                time_evac = time_evac
            )
            

        # Add betweenness centrality attribute to nodes
        betweenness_centrality = nx.betweenness_centrality(G)
        nx.set_node_attributes(G, betweenness_centrality, 'betweenness_centrality')

        # Add closeness centrality to nodes
        closeness_centrality = nx.closeness_centrality(G)
        nx.set_node_attributes(G, closeness_centrality, 'closeness_centrality')
        
        
        return G
    
    def __get_room_adjacencies(self) -> List[Tuple[int, int, float]]:

        # Get node indices for rooms and entrance connection
        node_indices = [i for i in range(len(self.rooms))]
        node_indices += self.entrance_connection

        # Retrieve room-door-room adjacencies, room-room adjacencies, and entrance-door adjacency
        room_door_room_adjacencies = self.connections_with_doors
        room_room_adjacencies = self.connections_without_doors
        entrance_door_adjacency = self.entrance_connection

        # Combine all adjacency information into a single dictionary
        edges = {}
        edges.update(room_door_room_adjacencies)
        edges.update(room_room_adjacencies)
        edges.update(entrance_door_adjacency)

        ## create door_width dictionary
        door_widths = {}
        for edge in list(edges.keys()):
            if edge in self.connections_with_doors.keys():
                ## room connections with doors are further weighted by the normalised value of the inverse of the door widths (larger door -> smaller weight, smaller door -> bigger weight)
                door_widths[edge] = self.door_widths[edge]
            else:
                ## room connections without doors are further weighted by 0.0, (preferable connection)
                door_widths[edge] = 0.0

        # Convert dictionary entries into a list of tuples with node indices and edge weights
        edges_and_weights = [(a[0], a[1], v) for a, v in edges.items()]

        return edges_and_weights, door_widths

    def __get_edge_attributes(self) -> Dict:
        edges_with_weights = self.edges_with_weights
        room_types = self.room_attributes
        edge_attributes = {}

        # Iterate over each edge and extract attributes
        for edge in edges_with_weights:
            # Extract room types of nodes connected by the edge
            node1_type = room_types[edge[0]]['room_type']
            node2_type = room_types[edge[1]]['room_type']

            # Store edge attributes with node types
            edge_attributes[(edge[0], edge[1])] = {
                'edge_node_types': (node1_type, node2_type), 
                'edge_opening_weight': self.edge_door_widths[(edge[0], edge[1])]
            }

            ## add door width to edge attribute
    

        return edge_attributes

    def __get_edge_midpoints(self) -> Dict:
        midpoints = {}
        edges = [(edge[0], edge[1]) for edge in self.edges_with_weights] 
        room_centers = self.__get_room_centres()

        for i, edge in enumerate(edges):
            if i < len(room_centers):
                midpoints[edge] = (round((room_centers[edge[0]][0] + room_centers[edge[1]][0]) / 2, 2), round((room_centers[edge[0]][1] + room_centers[edge[1]][1]) / 2, 2))
            else:
                midpoints[edge] = (round((room_centers[edge[0]][0] + self.entrance_door_centre.x) / 2, 2), round((room_centers[edge[0]][1] + self.entrance_door_centre.y) / 2, 2))
        return midpoints
    
    def __get_shortest_paths_to_exit(self, graph: nx.Graph) -> Dict:
            exit_node = graph.number_of_nodes() - 1
            shortest_paths = nx.single_target_shortest_path(graph, exit_node)

            def calculate_total_distance(_graph, route):
                total_distance = 0
                for i in range(len(route) - 1):
                    source = route[i]
                    target = route[i + 1]
                    total_distance += _graph[source][target]['weight']

                return total_distance
            
            for key in list(shortest_paths.keys()):
                distance = calculate_total_distance(graph, shortest_paths[key])
                shortest_paths[key] = round(distance, 2)
            
            return shortest_paths

    def __get_exit_times(self) -> Tuple[Dict, Dict]:
        """ Runs a monte carlo simulation on the markov chain, representing behaviour during fire. Giving predicted pre evacuation time per type of room. This function is stochastic, thus every time it is run it will return a different result"""

        markov_chain = self.mrk_chain

        ## Total Exit Time (Tn) = Pre-Evacuation Time (Tp) + Evacuation Time (Te)

        ## Pre Evacuation Time (Tp) Variables

        ## room types
        room_types = [self.room_attributes[i]['room_type'] for i in list(self.room_attributes.keys())]
        pre_evac_time_per_room = {i: 0.0 for i, room_type in enumerate(room_types)}
        evac_time_per_room = {i: 0.0 for i, room_type in enumerate(room_types)}
        
        ## expected time if sleeping
        pre_evac_time_sleeping = round(markov_chain.simulate_markov_chain(1, End_node),2)

        ## expected time if dressing
        pre_evac_time_dressing = round(markov_chain.simulate_markov_chain(4, End_node),2)

        ## expected time if feel concern
        pre_evac_time_concern = round(markov_chain.simulate_markov_chain(11, End_node), 2)

        ## expected time if rescue attempt
        pre_evac_time_rescue_attempt = round(markov_chain.simulate_markov_chain(14, End_node), 2)

        ## Evacuation Time (Te) Variables
        distance_to_exit = [self.room_attributes[i]['distance_to_exit'] for i in list(self.room_attributes.keys())]

        ## occupant speed (assumed at 0.7 m/s)
        ## t = d / s
        occupant_speed = 0.7 


        ## calculate pre-evacuation time per room, depending on prior task prediction, e.g if in bedroom, more likely to be sleeping / dressing

        for i, room_type in enumerate(room_types):
            ## add evacuation time
            evac_time_per_room[i] = round(distance_to_exit[i] / occupant_speed)
            ## add pre evacuation time
            if room_type in  ['LIVING_DINING', 'LIVING_ROOM']:
                pre_evac_time_per_room[i] = round((pre_evac_time_sleeping + pre_evac_time_concern) / 2, 2)
            elif room_type in ['ROOM', 'BEDROOM']:
                pre_evac_time_per_room[i] = round((pre_evac_time_sleeping + pre_evac_time_dressing) / 2, 2)
            elif room_type == 'KITCHEN':
                pre_evac_time_per_room[i] = pre_evac_time_rescue_attempt
            elif room_type == 'ENTRANCE_DOOR':
                pre_evac_time_per_room[i] = 0
            else:
                pre_evac_time_per_room[i] = round((pre_evac_time_concern + pre_evac_time_rescue_attempt) / 2, 2)

        return pre_evac_time_per_room, evac_time_per_room
    
    def assign_non_normalised_label(self) -> Dict[str, int]:
        """ Assigns raw labels to each floor plan, which are to be normalised once all labels are collected"""

        apartment_id = self.apartment_id
        graph = self.graph
        room_types = nx.get_node_attributes(graph, 'room_type')
        room_area = nx.get_node_attributes(graph, 'room-area')
        kitchen_node = [key for key in list(room_types.keys()) if room_types[key] == 'KITCHEN'][0]
        ## pre evacuation time
        room_Tp = [x for x in nx.get_node_attributes(graph, 'time_pre_evac').values() if x != 0]
        expected_Tp = Expected_preEvac_time
        Tp_diff = [round(x - expected_Tp,2) for x in room_Tp]
        Tp_average_difference = round(sum(Tp_diff) / len(Tp_diff),2)

        ## evacuation time
        room_Te = [x for x in nx.get_node_attributes(graph, 'time_evac').values() if x != 0]
        Te_average = round(sum(room_Te) / len(room_Te),2)
        if Te_average > 20:
            Te_average = 20
    

        ## centrality metrics
        room_between_cent = nx.get_node_attributes(graph, 'betweenness_centrality')
        room_close_cent = nx.get_node_attributes(graph, 'closeness_centrality')
        kitchen_betweenness_centrality = room_between_cent[kitchen_node]
        kitchen_closeness_centrality = room_close_cent[kitchen_node]
        kitchen_centrality = kitchen_closeness_centrality + kitchen_betweenness_centrality
        if kitchen_centrality > 1.25:
            kitchen_centrality = 1.25

        floor_plan_labels = {
            apartment_id: {
                'Tp_average_difference': Tp_average_difference,
                'Te_average': Te_average,
                'kitchen_centrality': kitchen_centrality
            }
        }

        return floor_plan_labels

    def save_training_image(self, width_pixels: float, height_pixels: float, dpi: int, transparent_background: bool, subfolder: str) -> None:
        plan_id = self.plan_id
        apartment_id = self.apartment_id

        os.makedirs(subfolder, exist_ok=True)
        filepath = os.path.join(subfolder, f"{apartment_id}.png")  # Include file extension and possibly more info
        
        try:
            colours = self.__give_colours()
            polygons = shapely.wkt.loads(self.plans[plan_id][apartment_id]['geometries_dict'])
        except Exception as e:
            # print(f"Error loading data: {e}")
            return
        
        fig, ax = plt.subplots(figsize=(width_pixels / dpi, height_pixels / dpi))
        
        try:
            for polygon, colour in zip(polygons, colours):
                x, y = polygon.exterior.xy
                ax.fill(x, y, color=colour)
            
            ax.set_aspect('equal', 'box')
            ax.axis('off')
            plt.savefig(filepath, dpi=dpi, transparent=transparent_background)
            plt.close(fig)  # Close the figure to free up memory
            # print(f"Image saved to {filepath}")
        except Exception as e:
            # print(f"Error saving image: {e}")
            if os.path.exists(filepath):
                os.remove(filepath)  # Remove the file if saving fails to prevent incomplete files

# %% [markdown]
# ### Save images dataset

# %%
def make_plan_graphs(plans, plan_ids, apartment_ids):
    labels = {}
    
    for i, plan_id in enumerate(plan_ids):
        for apartment_id in apartment_ids[plan_id]:
            try:
                plan = Plan(plan_id, apartment_id, plans, behaviour_class, room_weights)

                label = plan.assign_non_normalised_label()
                plan.save_training_image(224,224,300,True,'raw_saved_images') ## takes around 12-14 minutes to run for all plans
                labels[apartment_id] = list(label.values())[0]
            except Exception as e:
                continue
    return labels

# %%
plans_dataset = make_plan_graphs(plans, plan_ids,apartment_ids)

print(plans_dataset)
# Out:
# c:\Users\Anton\AppData\Local\Programs\Python\Python311\Lib\site-packages\shapely\linear.py:208: RuntimeWarning: invalid value encountered in shortest_line
#   return lib.shortest_line(a, b, **kwargs)
# {'6bc84fcd23b9ea762f0a6df24a3494fe': {'Tp_average_difference': -15.49, 'Te_average': 15.62, 'kitchen_centrality': 0.42105263157894735}, '72a19aac76685749b99f171f06bcb4dc': {'Tp_average_difference': -7.59, 'Te_average': 15.12, 'kitchen_centrality': 0.42105263157894735}, '26edfa6ffa688381f8fb3fb980699d04': {'Tp_average_difference': -24.24, 'Te_average': 12.43, 'kitchen_centrality': 0.7523809523809524}, '3cb493819701539d5d9a849994b1dcc3': {'Tp_average_difference': -29.58, 'Te_average': 13.65, 'kitchen_centrality': 0.7523809523809524}, '18bdb8292f56882c9c703b382a93f451': {'Tp_average_difference': 12.59, 'Te_average': 14.06, 'kitchen_centrality': 0.38461538461538464}, '994786144475853e82ccb8af8ab12588': {'Tp_average_difference': -13.98, 'Te_average': 18.71, 'kitchen_centrality': 0.38461538461538464}, '6aba7a1c7f879f920213dff9377d2ef0': {'Tp_average_difference': -56.37, 'Te_average': 11.65, 'kitchen_centrality': 0.4444444444444444}, '91de1d7de9f2e553a2126217f05bc3f9': {'Tp_average_difference': -5.78, 'Te_average': 17.56, 'kitchen_centrality': 0.38461538461538464}, '0380271db1856a8eeeb3dc2557ab3da8': {'Tp_average_difference': -15.77, 'Te_average': 15.98, 'kitchen_centrality': 0.38461538461538464}, 'ee1be5067f21a723fdebf8f6c2e84d01': {'Tp_average_difference': -53.3, 'Te_average': 11.74, 'kitchen_centrality': 0.4444444444444444}, '82d319fbb2ca4e477b62bae02a5f361c': {'Tp_average_difference': -32.36, 'Te_average': 16.26, 'kitchen_centrality': 0.7523809523809524}, 'd5d48f4fce4b153904062d9f38ffc333': {'Tp_average_difference': -56.1, 'Te_average': 14.61, 'kitchen_centrality': 0.42105263157894735}, 'f3c32bddd375a2feb04dbc3e8cc12a6c': {'Tp_average_difference': -27.79, 'Te_average': 11.39, 'kitchen_centrality': 0.7523809523809524}, 'ad6153b82a2c0e73abc36c4860f17b0b': {'Tp_average_difference': -18.13, 'Te_average': 18.8, 'kitchen_centrality': 0.42105263157894735}, '4f61679e4dbccd8a23a12778562ffe62': {'Tp_average_difference': -15.47, 'Te_average': 17.62, 'kitchen_centrality': 0.42105263157894735}, 'd47f8a6ccc6db3b1648c0a1ac44b500d': {'Tp_average_difference': -23.7, 'Te_average': 11.54, 'kitchen_centrality': 0.7523809523809524}, '5beff36d118bd474784d79012a4dfbf7': {'Tp_average_difference': -52.28, 'Te_average': 9.83, 'kitchen_centrality': 0.7523809523809524}, '936d0af85f6610174565a06932345115': {'Tp_average_difference': -21.19, 'Te_average': 15.27, 'kitchen_centrality': 0.42105263157894735}, 'c05890a75644463f0e470439eca7ad16': {'Tp_average_difference': -55.06, 'Te_average': 11.94, 'kitchen_centrality': 0.34782608695652173}, 'a66979ee9fea015f1b64293e74f703ae': {'Tp_average_difference': -22.19, 'Te_average': 10.89, 'kitchen_centrality': 0.5}, 'fee063dcc1820b55183aa05df8dd12fb': {'Tp_average_difference': -19.23, 'Te_average': 12.5, 'kitchen_centrality': 0.42105263157894735}, '25995782456509e8b015ad9b7f1047e3': {'Tp_average_difference': -13.4, 'Te_average': 12.62, 'kitchen_centrality': 0.5}, '5905b1637ae63c163ec006c99a20fbe1': {'Tp_average_difference': -35.4, 'Te_average': 13.7, 'kitchen_centrality': 0.7263157894736842}, 'b2b73b4ccece5612033b4d6f67d0f115': {'Tp_average_difference': 16.07, 'Te_average': 14.6, 'kitchen_centrality': 0.5}, 'ffd16600bf35704a1141d9d8f6759287': {'Tp_average_difference': -58.78, 'Te_average': 9.0, 'kitchen_centrality': 0.5}, '146c026718483b992bb46045b38c2d89': {'Tp_average_difference': -13.23, 'Te_average': 12.62, 'kitchen_centrality': 0.5}, 'b5d379fdb8df89ddefc33ecbc9744b84': {'Tp_average_difference': -28.23, 'Te_average': 12.5, 'kitchen_centrality': 0.42105263157894735}, '1f2b70469649bf86b46532ce11fad6d8': {'Tp_average_difference': -21.28, 'Te_average': 9.0, 'kitchen_centrality': 0.5}, '00943206427d7c573c39121db1ec5d98': {'Tp_average_difference': -23.54, 'Te_average': 12.5, 'kitchen_centrality': 0.42105263157894735}, '256d96de3ba9b9b8113b9471db0eb562': {'Tp_average_difference': -66.49, 'Te_average': 9.0, 'kitchen_centrality': 0.5}, 'a79e7f731375c8b47e7b25535ab3ddee': {'Tp_average_difference': -48.04, 'Te_average': 12.62, ' ...

# %% [markdown]
# ### Save labels

# %%
def normalise_labels(raw_labels):
    tp_avg_diff = []
    te_avg = []
    kitchen_cent = []
    normalised_labels_dict = {}

    for apartment_id in list(raw_labels.keys()):
        tp_avg_diff.append(raw_labels[apartment_id]['Tp_average_difference'])
        te_avg.append(raw_labels[apartment_id]['Te_average'])
        kitchen_cent.append(raw_labels[apartment_id]['kitchen_centrality'])
    def normalize_list(lst):
        min_val = min(lst)
        max_val = max(lst)
        range_val = max_val - min_val
        normalized_lst = [(x - min_val) / range_val for x in lst]
        return normalized_lst
    def z_score_normalization(values):
        """
        Normalize a list of values using Z-score normalization.

        Args:
            values (list): A list of numeric values.

        Returns:
            list: Normalized values using Z-score normalization.
        """
        # Convert the values to a NumPy array for easy mathematical operations
        values_array = np.array(values)
        
        # Calculate the mean and standard deviation of the values
        mean = np.mean(values_array)
        std_dev = np.std(values_array)
        
        # Normalize the values using Z-score normalization
        normalized_values = (values_array - mean) / std_dev
        
        return normalized_values.tolist()
    
    norm_tp_avg_diff = normalize_list(z_score_normalization(tp_avg_diff))
    norm_te_avg = normalize_list(z_score_normalization(te_avg))
    norm_kitchen_cent = normalize_list(z_score_normalization(kitchen_cent))

    def average_lists(list1, list2, list3):
        combined_list = []
        for elem1, elem2, elem3 in zip(list1, list2, list3):
            average = (elem1 + elem2 + elem3) / 3
            combined_list.append(average)
        n_v =  normalize_list(combined_list)
        return n_v
    
    normalised_labels = average_lists(norm_tp_avg_diff, norm_te_avg, norm_kitchen_cent)
    for i, apartment_id in enumerate(list(raw_labels.keys())):
        normalised_labels_dict[apartment_id] = round(normalised_labels[i],1)
    return normalised_labels_dict

# %%
Normalised_Labels = normalise_labels(plans_dataset)
print(Normalised_Labels)
# Plotting the histogram
# plt.hist(Normalised_Labels, bins=10, color='blue', edgecolor='black')

# # Adding labels and title
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.title('Histogram of List of Numbers')

# # Displaying the plot
# plt.show()

with open('training_plan_labels.json', 'w') as json_file:
    json.dump(Normalised_Labels, json_file)
# Out:
# {'6bc84fcd23b9ea762f0a6df24a3494fe': 0.4, '72a19aac76685749b99f171f06bcb4dc': 0.5, '26edfa6ffa688381f8fb3fb980699d04': 0.4, '3cb493819701539d5d9a849994b1dcc3': 0.5, '18bdb8292f56882c9c703b382a93f451': 0.3, '994786144475853e82ccb8af8ab12588': 0.6, '6aba7a1c7f879f920213dff9377d2ef0': 0.3, '91de1d7de9f2e553a2126217f05bc3f9': 0.6, '0380271db1856a8eeeb3dc2557ab3da8': 0.4, 'ee1be5067f21a723fdebf8f6c2e84d01': 0.3, '82d319fbb2ca4e477b62bae02a5f361c': 0.6, 'd5d48f4fce4b153904062d9f38ffc333': 0.4, 'f3c32bddd375a2feb04dbc3e8cc12a6c': 0.4, 'ad6153b82a2c0e73abc36c4860f17b0b': 0.5, '4f61679e4dbccd8a23a12778562ffe62': 0.5, 'd47f8a6ccc6db3b1648c0a1ac44b500d': 0.4, '5beff36d118bd474784d79012a4dfbf7': 0.4, '936d0af85f6610174565a06932345115': 0.4, 'c05890a75644463f0e470439eca7ad16': 0.3, 'a66979ee9fea015f1b64293e74f703ae': 0.4, 'fee063dcc1820b55183aa05df8dd12fb': 0.4, '25995782456509e8b015ad9b7f1047e3': 0.5, '5905b1637ae63c163ec006c99a20fbe1': 0.5, 'b2b73b4ccece5612033b4d6f67d0f115': 0.4, 'ffd16600bf35704a1141d9d8f6759287': 0.2, '146c026718483b992bb46045b38c2d89': 0.3, 'b5d379fdb8df89ddefc33ecbc9744b84': 0.4, '1f2b70469649bf86b46532ce11fad6d8': 0.2, '00943206427d7c573c39121db1ec5d98': 0.3, '256d96de3ba9b9b8113b9471db0eb562': 0.3, 'a79e7f731375c8b47e7b25535ab3ddee': 0.3, 'e40062947dedd546c7cb59307632973b': 0.5, 'ae63a5a3304df6fa11002e5280a10323': 0.6, '0c9653fbfbb430fbb90ca28be48fbf93': 0.3, '3ab282be7e363633190fb93c9ba9ca93': 0.7, 'f42f265e8b0b53d2d01009e767466a07': 0.5, '9f7a9bc727e40a67816138fa1759a85c': 0.5, '62df4db96d1646383c17196bbe4c9813': 0.5, 'fd342a9935d2e7e94feb0233eb33db9e': 0.3, '8081ed3fb644b935731c512eca16f418': 0.6, 'c1601bdbc5e227c1f5ffde4b107664c2': 0.4, '72a49fe65d0bd5585bd520b208741289': 0.4, 'cc5af444b3455439579026d070997dee': 0.5, 'c890c92c8e909320520c0c7303e6ba22': 0.4, '5e75963f25b7f28ac5715c1442fa6736': 0.4, '1153eaedaa72a8a8eab5d8076a451e3b': 0.5, '80bc39dc3c226e2069d99226c007bd23': 0.5, '3ec234e29123a0b575f255e46b4efd63': 0.7, 'ea363e8589bb09637b2e8af987c6bce9': 0.6, 'd14e5435f4d3feebd62f6278c33c25e2': 0.3, 'edb8e91fdd60a79bf64382557a9686ba': 0.4, '44b2aa3d2c854bf12ca7e3fb471e8df7': 0.3, '343cb1aa00880c1875468c058f2c83b4': 0.4, 'ce914664158efafb4081a8f01485d49c': 0.4, 'b9a23e4c1eb3fa9efba38acdf376ab51': 0.4, 'e09b12d04e1614e144062e166d10b36f': 0.3, '2d358a74be4322278dc9c8d13e81c01a': 0.4, '54cdba46e2742f4fe395c89c898a5dcc': 0.3, 'd06ffdff72b20eea025421a63733b525': 0.4, '027ac677181d33f178fae27ded2b6905': 0.4, '0de83da93220fa2d66ed93f56af4a209': 0.4, '2e3215269528fa32732195f806dfae0c': 0.4, 'a4af1b5f9a3be7b39758a062da9131ac': 0.3, '019b2a469d254e8bdca48a4b780d64c4': 0.5, 'b21bfda8fd250c13608df091cd42dba6': 0.4, '78543b1ba39330f198c0d658cc69e87b': 0.4, '9017c563cfa4fd2211af129b0680d920': 0.4, 'a01b8f46618709319da411b9846bcf2d': 0.5, '184b3aed3b741732379e90ae42877fb5': 0.5, '8d512cac3d20c84c8b65a00eed800979': 0.4, '55db0c52468d390ba2c1fe5f7c21434f': 0.4, 'afa8ad96defa43f9c495c4710911c5ac': 0.4, 'bf8b76c29e280d5e22d6f46262dc7127': 0.3, '7a000c5b41ba8544386bc5df8b24f7b0': 0.4, '8b4d7efff2ddcc6061f0ac3c757938a6': 0.4, 'e24033fea4a932dd86f52a3285ef848b': 0.4, '05208d276d24d1303a7d3804495d3087': 0.4, '0a27665d9f6b04592d562d2dec862c26': 0.3, '6bb079b49ef8e0384838095782396826': 0.3, '434708fefe36e4ccf53b3a72afa8edb3': 0.3, '3977698d441d403c30da759607684fb4': 0.3, 'b64b662d1b7819137c498f6978f3bad3': 0.4, 'c34f339a1bd4f9ef63a60409c8349d57': 0.3, '51aa3dc93d145aaa93f3572c94860337': 0.4, '0a99713bad90f26aecaa0f0ea0adb573': 0.2, '6e497a505341016c0b1f0d9486b37311': 0.3, 'c49a1a731c6631ce80dd6fcfc24a116b': 0.4, 'bc5db5868e2b7a9758dede7d8a9bf850': 0.2, '4db9aadbcab9fa75aeef7f98c5fb8468': 0.2, '86e4c5e7763da102296c9db6d47e0dd7': 0.3, '027bd31d3566ce61d30c946b40032a99': 0.4, 'd0cd3ce0389790a91ec7dcb71a6df589': 0.5, '94404e2b72813913d72ba69a2e1c3d2a': 0.3, '00e9a48a0c6d5691aac7da153efa62b0': 0.4, 'd28ac3ce15c0f1f327895e53bfce966c': 0.7, 'e079a2af6dda18be67297be6155f29ac': 0.1, '26d25a91f50d6d73d3b6edc9ffc8b2f2': 0.3, '5cc159c5d025567ffedc2 ...

# %% [markdown]
# ### Reorder images to train and test datasets

# %%
## load dataset labels from json to python dictionary

with open('training_plan_labels.json', 'r') as file:
    labels = json.load(file)

# %%
unique_labels = (set(labels.values()))
print(unique_labels)
# Out:
# {0.4, 0.5, 0.6, 0.2, 0.3, 0.7, 0.1, 0.0, 0.8, 0.9, 1.0}

# %%
label_to_foldername_mapping = {
    0.0: 'score0',
    0.1: 'score1',
    0.2: 'score2',
    0.3: 'score3',
    0.4: 'score4',
    0.5: 'score5',
    0.6: 'score6',
    0.7: 'score7',
    0.8: 'score8',
    0.9: 'score9',
    1.0: 'score10'
}

# %%
def split_images_dataset(source_folder = 'raw_saved_images', train_folder = 'dataset_images/train', test_folder = 'dataset_images/test', training_size_percentage = 0.7) -> None:

    """ Moves images from raw folder to split into training and testing sub sets and also assign labels from dataset_labels.json"""

    # List all images
    images = os.listdir(source_folder)
    random.shuffle(images)

    # Calculate the split
    split_index = int(training_size_percentage * len(images))

    # Split into train and test sets
    train_images = images[:split_index]
    test_images = images[split_index:]

    # Move images to train folder
    for img in train_images:
        src_path = os.path.join(source_folder, img)
        dest_path = os.path.join(train_folder, img)
        shutil.move(src_path, dest_path, copy_function = shutil.copytree)
    # Move images to test folder
    for img in test_images:
        src_path = os.path.join(source_folder, img)
        dest_path = os.path.join(test_folder, img)
        shutil.move(src_path, dest_path)

    print("Dataset split completed.")

split_images_dataset()
# Out:
# Dataset split completed.

# %%
def order_images_dataset_to_classes(train_folder = 'dataset_images/train', test_folder = 'dataset_images/test', class_mapping = label_to_foldername_mapping):

    # create class folders if they dont exist
    for key, value in class_mapping.items():
        class_folder = value
        train_destination_folder = train_folder +  '/' + class_folder
        test_destination_folder = test_folder + '/' + class_folder
        print(train_destination_folder)
        if not os.path.exists(train_destination_folder):
            os.makedirs(train_destination_folder)
        if not os.path.exists(test_destination_folder):
            os.makedirs(test_destination_folder)

    def move_to_class_folders(source_folder, class_mapping):

        images = os.listdir(source_folder)
        for img in images:
            src_path = os.path.join(source_folder, img)
            labels_key = os.path.splitext(os.path.basename(src_path))[0]
            label = labels[labels_key]
            class_folder = class_mapping[label]

            dest_path = os.path.join(source_folder, class_folder, img)
            print(dest_path)
            shutil.move(src_path, dest_path)

    # move_to_class_folders(train_folder, class_mapping)
    move_to_class_folders(test_folder, class_mapping)

order_images_dataset_to_classes()
# Out:
# dataset_images/train/score0
# dataset_images/train/score1
# dataset_images/train/score2
# dataset_images/train/score3
# dataset_images/train/score4
# dataset_images/train/score5
# dataset_images/train/score6
# dataset_images/train/score7
# dataset_images/train/score8
# dataset_images/train/score9
# dataset_images/train/score10
# dataset_images/test\score4\00024dcb907dc1671ef48af550271427.png
# dataset_images/test\score2\00048321bf465caba119f73d57093299.png
# dataset_images/test\score3\0049d0f1ce0669f7975171c7c9689327.png
# dataset_images/test\score3\00535fec0cb98946f5ad1d394faf88da.png
# dataset_images/test\score3\006b3c08e777075a631beef4cc6ce66a.png
# dataset_images/test\score7\0072547bbedc9bce47fe78290f1f2f81.png
# dataset_images/test\score4\007b7ed02d764aca8b5bc12f00486130.png
# dataset_images/test\score2\00814d20aa77dddf10258079deeacd95.png
# dataset_images/test\score6\00844d651ee96502354d7352ae137dbd.png
# dataset_images/test\score6\0091fb8f1f33381387d61075e7a96696.png
# dataset_images/test\score3\00943206427d7c573c39121db1ec5d98.png
# dataset_images/test\score3\00b820be2519b20e949984ea49942469.png
# dataset_images/test\score3\00bc60c035283190813295f68812fae0.png
# dataset_images/test\score6\00be71ee5c6f14add73d1f54ae5fb4c3.png
# dataset_images/test\score5\00dc24b4513cf7845a5638b2a57401de.png
# dataset_images/test\score2\00dd23f4e91a740c818c7fe42ec96afe.png
# dataset_images/test\score4\00e9a48a0c6d5691aac7da153efa62b0.png
# dataset_images/test\score5\00eb01f4657bb66191063b9f99f3d82e.png
# dataset_images/test\score4\00f7087ff7210a69dcbbb0aa05a42a75.png
# dataset_images/test\score6\00fdd8aff0dfac2b7937b063983d0c8c.png
# dataset_images/test\score6\0101e906abc3ad4d85872cc633fa2e4f.png
# dataset_images/test\score5\012473986798aef17cebda4cd9381e9e.png
# dataset_images/test\score3\0135253d47bd8f35f97d9e8b48dd0c15.png
# dataset_images/test\score4\01369246412776a72f63a004845d6361.png
# dataset_images/test\score5\01373a2018c563703e45472fc16b0c22.png
# dataset_images/test\score4\013ca3d3115cd833e024a0007ec104f4.png
# dataset_images/test\score4\013d2760690d2fcbbdc438de37ba88f0.png
# dataset_images/test\score3\0141572b9a811f773837004cc8f7e9e1.png
# dataset_images/test\score6\0147fc30882bd3fa6c9da40539312799.png
# dataset_images/test\score7\01519fe33d6d1368093c7bb7fe52ae8d.png
# dataset_images/test\score2\0157cc9922d4dd1958e7627d6c07e538.png
# dataset_images/test\score4\0162d655563ba1feb940c894159a67d4.png
# dataset_images/test\score2\016533a565a4985bc38c639dcdd22874.png
# dataset_images/test\score5\016723b97d2615d147bac2a387d1e05d.png
# dataset_images/test\score4\0169937ca878a5399df103f7b8c088e6.png
# dataset_images/test\score3\0182a3fc4bcc639aa14c81dcf2cc6ad0.png
# dataset_images/test\score5\018dd45708ec146cb8203dfd6ec44e45.png
# dataset_images/test\score3\019182351a5160269d80bcf38fcc1206.png
# dataset_images/test\score3\01937c6ae54fde03b3f19e21f090d1e5.png
# dataset_images/test\score4\01ad9ff2c6b4b8b2a55c4425d9fd50f2.png
# dataset_images/test\score5\01af88585f5644ddd00c6c99361fbb7a.png
# dataset_images/test\score4\01b2d320f94f21870bf96c0e60fe6e62.png
# dataset_images/test\score3\01b7613176975eec08e0dab340835edb.png
# dataset_images/test\score3\01bce1ea00989ae1e4acb9719ffbb297.png
# dataset_images/test\score5\01c437fa124feb762160dfc78c65f560.png
# dataset_images/test\score5\01cab97540c727fcda1b1d9b611da5e3.png
# dataset_images/test\score3\01db73074f42f000787295494e1cfada.png
# dataset_images/test\score2\01dc7a567e67444c72cf1d52dbbfcc9e.png
# dataset_images/test\score4\01e8bf69fad2f7cb53069e801660c6a1.png
# dataset_images/test\score3\01eed0d326024e31e5f5d9a3d3eb0be2.png
# dataset_images/test\score3\01ff218c7cf69e15f9588be6acbb41b2.png
# dataset_images/test\score4\020059fa2fdb9c5ccc1eb90639037fef.png
# dataset_images/test\score4\0203b6e04b6b96ff74be77647916464d.png
# dataset_images/test\score4\0204c0830dae96be1db78fd121f8b086.png
# dataset_images/test\score3\0215d03f9e552137b74bd9ae2892c420.png
# dataset_images/test\score3\021854b0ece39982bd29c0fc9b154743.png
# dataset_images/test\score3\021f827eee1a7aa48dc8fe2bd3ceece5.png
# dataset_images/test\score3\02436365e0b0d5931290f32eb2322e93.png
# dataset_images/test\score4\0265de3274ad106e17810b784a87a280.png
# dataset_images/test\score5\0267408f26b0d630f252fc151fe6ad26.png
# dataset_images/test\score3\02780adb071f66b64468c2b275986024.png
# dataset_images/test\score3\0280eea8be89ea55637a7f62d5a7ba40.png
# dataset_images/test\score5\0282bfdfbbecc0661e68cf8ac0b7ae84.png
# dataset_images/test\score5\02987345375d285524a8bec7d2db3637.png
# dataset_images/test\score2\02990ee7d3807157d506d8c1e39c66f9.png
# dataset_images/test\score5\02bded67f3b972af1e6dceb2449b42d4.png
# dataset_images/test\score2\02c99a72d67576cc29ff2dd5a26de73b.png
# dataset_images/test\score4\02cc85ac04a54341a95a6267b13792ee.png
# dataset_images/test\score5\02cca839c8d23bdc7226af5ce6656959.png
# dataset_images/test\score2\02e836243870de67ea75746fd357d253.png
# dataset_images/test\score6\02ea6330f15524a710b676e0c55b7d68.png
# dataset_images/test\score2\02eca191523878079ddbbae82333a10c.png
# dataset_images/test\score5\0301c60f7c6ca9c4ffbe5d83305a7ac1.png
# dataset_images/test\score5\03045259c40d4a30d8d160337cb5100f.png
# dataset_images/test\score2\030dfb437812534ef2701780e2a73f02.png
# dataset_images/test\score4\0324e750c34ae1894a42e83339554e46.png
# dataset_images/test\score9\03259ded3693e46d7970b1f6a26a9a19.png
# dataset_images/test\score3\0347e0c2bc9a2fba62aa2d13f11e8022.png
# dataset_images/test\score4\0354c67295559573348cb5b6e514798e.png
# dataset_images/test\score6\0383d7283c666e9404759a16a1e6727e.png
# dataset_images/test\score2\0390ce9f4e53276b309a3308c4942210.png
# dataset_images/test\score4\03a223da24c3d9be1ea9274870df599e.png
# dataset_images/test\score4\03af551a643c25d0f9fed0f0631b94f2.png
# dataset_images/test\score3\03b370362fef8c4637c07a5b8acd0dcc.png
# dataset_images/test\score5\03d17511ff8c631ad4a6a290a1d4e2b1.png
# dataset_images/test\score4\03e686e08de66ef0a7ca7f73b82e7064.png
# dataset_images/test\score4\03f8ad4b2594d17d32ba78f52e5aadbd.png
# dataset_images/test\score3\041d12f87d3648565eb090dbef7b35c0.png
# dataset_images/test\score2\041ee068a9b6d720d2ec0dc85792136a.png
# dataset_images/test\score4\04333be48bdb9b83ee17214a5be173aa.png
# dataset_images/test\score6\0452d591d4529b762ce71262ae9e1458.png
# dataset_images/test\score7\04582c76d142cade281beeef78c8f52a.png
# dataset_images/test\score6\046c343022b93ff25b1eeeb22f80a4bf.png
# dataset_images/test\score3\04719ee9763402f8fd37eefb75367398.png
# dataset_images/test\score3\0477b17a1105d717b5e5590814c3aef4.png
# dataset_images/test\score6\0485ba7c6d2fce1ce9fe1e42ce0537d6.png
# dataset_images/test\score6\04bba15c3495a8e504fc2419c0783ec4.png
# dataset_images/test\score4\04bef280b8a073203e73b871e62ae78e.png
# dataset_images/test\score4\04cd2e9cfc466bca1bcc20cb2abfc791.png
# dataset_images/test\score2\04d3edfd4aba863c404502947c8a3714.png
# dataset_images/test\score2\04e0cd2d12a4d954240a12b63746d175.png
# dataset_images/test\score3\04f28d2bbb6df5ea2e70d6fcc8ef6926.png
# dataset_images/test\score5\052bd79a30eeda56a3871a42c06eaf8b.png
# dataset_images/test\score6\05555fbad1205e94eb7caf52ef066974.png
# dataset_images/test\score6\055667101823cb66ac78d5ba1f203987.png
# dataset_images/test\score5\0557c7d2366bb3ff6c81ca41a474f2c2.png
# dataset_images/test\score6\05751f70d6d2a3920c525175f450f80c.png
# dataset_images/test\score6\05a6552b5eb39f40545c11c716a69f3e.png
# dataset_images/test\score3\05e87702d4b616c7da608b0b14f57b58.png
# dataset_images/test\score5\05f6d84277f9b0a3e9e440153e666227.png
# dataset_images/test\score6\06129aac6fd34302edda022e5bca9f8f.png
# dataset_images/test\score3\0614a1add262d0baf30aa7612ae50bdb.png
# dataset_images/test\score3\06267ab86c805f2705e535260560abcc.png
# dataset_images/test\score4\062cc9172a0a5381d5649966bccbeba5.png
# dataset_images/test\score6\062ec9c29f52697c288a48dc5a8bf755.png
# dataset_images/test\score1\0643b702444ba4b091c1d61abafee68f.png
# dataset_images/test\score4\0649e588455104625869a451bb5a89eb.png
# dataset_images/test\score3\065589ef5af88ff22f3d7fce17351097.png
# dataset_images/test\score3\0672193526a1db7b7a5af65cb2ee7d07.png
# dataset_images/test\score5\067b3908bb94c551c9f4219026aac810.png
# dataset_images/test\score5\067bdd811e5fb2c4cd018d0dd015923e.png
# dataset_images/test\score2\0682ff29c955d4121b3fbc85dbe37f19.png
# dataset_images/test\score6\06851837cf266469b5935daf1292667d.png
# dataset_images/test\score4\068cc7de7bc5e4d3178fb3035f13c412.png
# dataset_images/test\score5\06b6490a5ebd4a0f82cbeb213bc64c6b.png
# dataset_images/test\score4\06e22929ff0eb8aa812131d643644b5a.png
# dataset_images/test\score1\06ea7750b07c307847088e9cd3f4a81b.png
# dataset_images/test\score6\06fd3d913f0d7d2c5a2882b9967fabc8.png
# dataset_images/test\score4\06fdaad13cdf5b0bbdc5d580c4e67e8a.png
# dataset_images/test\score5\0722220f1b109bf302066fd8452ed400.png
# dataset_images/test\score4\072413f476741bb936065b6e798625b6.png
# dataset_images/test\score3\072448625482cf6d1e91ccb60a019345.png
# dataset_images/test\score4\073870ceee1bc9ccf5104bab36dd0843.png
# dataset_images/test\score4\075aa158f4069accbcd890fc390cb005.png
# dataset_images/test\score5\07812e3cfc0d2bbb89a3bb31b6ab14f2.png
# dataset_images/test\score6\0785df5ac651fc10af144c8de5c6dd0f.png
# dataset_images/test\score3\0786fc473c41b72805c85ec25d3ecfc6.png
# dataset_images/test\score4\07d57cb8cc980b62fa9ed2d42c3b7a50.png
# dataset_images/test\score4\07d7d06fd99d5a71e8ad2713741d343a.png
# dataset_images/test\score5\080d5c638673150fc25b582cd4f1f8fc.png
# dataset_images/test\score5\0814500979e71fae7fc1c6ec4b517669.png
# dataset_images/test\score4\083b2a1b38eb6b52afe41d0df39d5008.png
# dataset_images/test\score2\08523ff110bb7e9385e67ee832bdb6b4.png
# dataset_images/test\score5\085976984cfa30cb04536eeeb17de701.png
# dataset_images/test\score3\085ca09975f3b438248a62f30ebdb8bb.png
# dataset_images/test\score3\089529779363f1d05f0aef9b72b83276.png
# dataset_images/test\score3\089a4066c07a26f283851b22564dc51c.png
# dataset_images/test\score4\08a9fa167bad8697c2f42846da80d94b.png
# dataset_images/test\score5\08be3d7111f0e5ec7bb26ed5f6414db9.png
# dataset_images/test\score7\08cdb953db56e973dc449f505ea65201.png
# dataset_images/test\score2\08ce20c673adb7ff9217fd82729e23cb.png
# dataset_images/test\score3\08daf59ed1b02532316b3bd42b3d7d59.png
# dataset_images/test\score2\08e2de61490d0b04f860c40f330f5b23.png
# dataset_images/test\score3\08f7228cfba13c3753b6be411c4032a6.png
# dataset_images/test\score5\090c6155bc82a063aa93c7a1fe2c83fd.png
# dataset_images/test\score6\090e86b8a1fd11ad116d372be291b9d6.png
# dataset_images/test\score5\091766111b914008fc246f0d5740fa34.png
# dataset_images/test\score4\0932df0a365aa17feed81a767b76f548.png
# dataset_images/test\score4\093f7f1739392dd1e5701846a4408b90.png
# dataset_images/test\score2\0966be18cb0a15482df849cc3860396c.png
# dataset_images/test\score2\0992f598f6b1d6d896c16340c7de7b01.png
# dataset_images/test\score4\0995b099794a44f0c8a0a1e312483047.png
# dataset_images/test\score4\09ce54b843713bf0a0e5b61ac1ba17da.png
# dataset_images/test\score3\09e9b8b18cc3b7f212272b36fa0cc537.png
# dataset_images/test\score4\09fdf020304334cdcfeead27198726c5.png
# dataset_images/test\score4\0a1693417e452f68fafcb9a0b561e63d.png
# dataset_images/test\score3\0a2b42654c569c50872f8fb7ac883782.png
# dataset_images/test\score3\0a2e5be20266f8e5de2e7033295aba9c.png
# dataset_images/test\score4\0a63882b51baac5e3cce7f7337cd90f1.png
# dataset_images/test\score2\0a7188447e86774f4ae086bc4c5cb799.png
# dataset_images/test\score4\0a90945aca9088812c75c7ed2685a311.png
# dataset_images/test\score3\0aa451fe3bd41b9d08da117cdf92cee1.png
# dataset_images/test\score3\0ada885d7b2c9223ef7d9d925864f6b5.png
# dataset_images/test\score4\0adb78626402530e9a5bdf193e559ac7.png
# dataset_images/test\score3\0add5a842270bd0c7e16befa91fcd258.png
# dataset_images/test\score1\0ae47c06cd549cec74c937dfdb898e87.png
# dataset_images/test\score3\0aed2a41c4c2730d4333ca71ef08c6e2.png
# dataset_images/test\score3\0aef1b0e671349c78d750a6381f1aca5.png
# dataset_images/test\score3\0b08fd44d5250e6f4c94c09b64efad91.png
# dataset_images/test\score3\0b3f71e7e07e3e9c98a4735b8b5d0c8f.png
# dataset_images/test\score3\0b4db09c32bb774f48578605e703c7bc.png
# dataset_images/test\score2\0b561095c3a1e4744ab1fa24aa19d0fe.png
# dataset_images/test\score3\0b635ff11daf9bfbf27ed6298eecbbb2.png
# dataset_images/test\score5\0b77c2573ab0e828b95f581aad97ad5f.png
# dataset_images/test\score4\0ba405d8957371107d8d0eee30051710.png
# dataset_images/test\score4\0bb3a80c78ae68445fa84abd908e8bc6.png
# dataset_images/test\score2\0bc60be3a5c8a260acfcdfc0a4f871ef.png
# dataset_images/test\score4\0bde1ced477cc7f76d7b0b032c3e7f9b.png
# dataset_images/test\score4\0bf141cf4abb64e2e623458abc957a0d.png
# dataset_images/test\score5\0bfa448b4a3419416ccddf18ca003c88.png
# dataset_images/test\score3\0c043c36c8bb8c307913f4dfe6d11cae.png
# dataset_images/test\score3\0c0db8b5235a480169938deae168abb8.png
# dataset_images/test\score4\0c370c2af94ee73fab4aae15ea1dadbb.png
# dataset_images/test\score3\0c3928b1e1cf0457cb0ad220bcc42fca.png
# dataset_images/test\score3\0c60b2024efa0a6bffc33ad3d2b7898a.png
# dataset_images/test\score1\0c63853df500d0247347fed88533904a.png
# dataset_images/test\score3\0c77a04c318c1bf484baee1df5e9c5b0.png
# dataset_images/test\score3\0c9653fbfbb430fbb90ca28be48fbf93.png
# dataset_images/test\score4\0ca8f4eb0930e546cd7ab6a4fa579c17.png
# dataset_images/test\score5\0caa0ebb3e5c5368b8fcb5955a6924c8.png
# dataset_images/test\score2\0ccd381a6f0432c832b360ff307fc589.png
# dataset_images/test\score4\0cdcbf134fcb38ef5bf64eb63f5c8889.png
# dataset_images/test\score3\0ce30bedda59675ac0a27c3a7206a248.png
# dataset_images/test\score8\0cf1b7e3b74ce46c8fee4918bb322b8a.png
# dataset_images/test\score6\0d0d34c5c5a3522a4717a88cd5ec5258.png
# dataset_images/test\score6\0d11abb4a4e1e4ed78241a88b51f97d1.png
# dataset_images/test\score4\0d3cd5dbb5b9960d53d5a95de90d18d8.png
# dataset_images/test\score3\0d3d3e4b65c91ad668445516f9694982.png
# dataset_images/test\score4\0d6fe8e6cb3dd6707bac2c33489fe1e1.png
# dataset_images/test\score3\0d854a65ada60f80ea40d0ee404ea090.png
# dataset_images/test\score3\0dbe1e400931df3112fefb27c57fe069.png
# dataset_images/test\score4\0dcf8d34558f058a16b68ffc1df57879.png
# dataset_images/test\score2\0dd59d70ed3e571a100aa8bbcde09e24.png
# dataset_images/test\score3\0e3095c26cd8c5475321ff3e911a73d6.png
# dataset_images/test\score3\0e6b25c34e622afa56d394fa78388cee.png
# dataset_images/test\score3\0e6f66caddbe2729ccf13c4aba757d95.png
# dataset_images/test\score3\0e7144504e879dd1f9a0aeabc8c9d63a.png
# dataset_images/test\score6\0e8efcb5146cfe725f35fb5687999271.png
# dataset_images/test\score4\0e954931d5e710ec6227792df7d3cc89.png
# dataset_images/test\score7\0ea9a12191d9b475fcc5821318bdbea1.png
# dataset_images/test\score2\0eaa64e43dd3c1a4a4ec574a28715a45.png
# dataset_images/test\score4\0ec57f65599fb0c2b7d1bde669f59bf9.png
# dataset_images/test\score4\0eccd553b8df292692808059a32f9328.png
# dataset_images/test\score3\0ed09768f6cb5bd8794da1fe8b771f5c.png
# dataset_images/test\score4\0ee75da3c0716de6aa6acaf7d02185eb.png
# dataset_images/test\score3\0eed1cf716628ec3e42f6ba73b07bd8d.png
# dataset_images/test\score5\0ef213b10f93cd98b5e9583084b270ba.png
# dataset_images/test\score4\0efd5c87712b8df8384fd0a9b5430e95.png
# dataset_images/test\score5\0efdc8f029e221ca8d8d28b9ab8b600b.png
# dataset_images/test\score3\0f11c7f958983007590a3b6fc8c5b52d.png
# dataset_images/test\score5\0f51145503204340d175c9b634e1cc58.png
# dataset_images/test\score4\0f55efafd86eadff40a4a1f5839f31e4.png
# dataset_images/test\score4\0f571ebf15be10529eb95b22a3c1561e.png
# dataset_images/test\score4\0f7129acf1a94e965622dc54ced1ae1c.png
# dataset_images/test\score3\0f85102ce1787a46a2ea497ee49ae538.png
# dataset_images/test\score5\0f9a71910eeed98d83815be8f779eb1a.png
# dataset_images/test\score1\0fa614ad529213ceec136d3b339c9981.png
# dataset_images/test\score5\0fb25f196244830876e89240142f780b.png
# dataset_images/test\score3\0fc75122e6e3b36d6a7d9eb76f294ab0.png
# dataset_images/test\score3\0fcff6555cb7e94ce575348f30ae5a6e.png
# dataset_images/test\score8\0ffc7294f345fbd454b595221142af95.png
# dataset_images/test\score5\100832dc1e010e9aee2f4a91a362f250.png
# dataset_images/test\score2\100ee990b7be80c747602424bed4f010.png
# dataset_images/test\score6\101bb61d9ff38c90c59d010837ef79bc.png
# dataset_images/test\score4\102bcb71ec0adb1de1234ce926bd3efe.png
# dataset_images/test\score1\10329f65cc7c7ff71d8713553fef422b.png
# dataset_images/test\score3\1044634c9410e458c133bc42dd9b6be9.png
# dataset_images/test\score5\105f3173f18375f6c26c3fdaeac50b30.png
# dataset_images/test\score4\1060ff5a5af410b1e9c5be7dee6739fa.png
# dataset_images/test\score4\109eaa271170de2765e496fdf27d8513.png
# dataset_images/test\score4\10ad916f1c1c53465456e6e1dfa900e2.png
# dataset_images/test\score3\10ce5b6571111a2347bf614816144437.png
# dataset_images/test\score5\10d30f81a137833d6e126794ef9e10f3.png
# dataset_images/test\score5\10db4c7c67b65e320c541f9cf16da1f4.png
# dataset_images/test\score6\10e8408b9e5533e862b9185f7e3c40d6.png
# dataset_images/test\score3\10f5cc729603e535f9f50212f9bddd77.png
# dataset_images/test\score6\10f646ba3d29668c11cdd38d9a6a3e07.png
# dataset_images/test\score6\110b8b57123df021af18b2a6018963dc.png
# dataset_images/test\score2\11346437afbcd34c12893670f082281c.png
# dataset_images/test\score4\114d7f4ca5e1fc4677d9111c09fe4978.png
# dataset_images/test\score3\11547f1d562bb136ad65fb4de20b2f22.png
# dataset_images/test\score4\11555cc61a43ebb661f6ec53c6f87726.png
# dataset_images/test\score2\1170ab29d3b5d5416b483b93a93c127f.png
# dataset_images/test\score3\1182e2498e3d24ec754ff1106bfe6aa1.png
# dataset_images/test\score5\119d8c3be6f01ccc165c52f3582e184b.png
# dataset_images/test\score5\11ab6191b137cc9ff085f5736f57fd66.png
# dataset_images/test\score6\11af614cbe917fb813ef72f9635d2e40.png
# dataset_images/test\score3\11c97e145dde9e16eee54c095e7352a5.png
# dataset_images/test\score4\1206d069c4624d500defd84bbbd6e521.png
# dataset_images/test\score6\1235cb78af6b6d4a53e8a70e28412a7b.png
# dataset_images/test\score5\12398322514fd7ea0ad6da1f058cbae6.png
# dataset_images/test\score4\123b23275872a6dd7851835a1c1508ab.png
# dataset_images/test\score3\1245b5bf1934335ee1ba8217f29169fd.png
# dataset_images/test\score3\12554be2446a757cae3f80bcb9f79483.png
# dataset_images/test\score1\1280ecd8e7599c5790a6e4f6a02b88a7.png
# dataset_images/test\score4\12810517f72ff855613cf3b64f0ddbb1.png
# dataset_images/test\score4\128bf5d403bed1c9ad47bea0fafd607e.png
# dataset_images/test\score6\12b20014fc9af495be788ca866630964.png
# dataset_images/test\score3\12ba90c7af9a8a5e41ec63215df7abe7.png
# dataset_images/test\score1\12bfe7b856cb5c1dae9198053c1a6998.png
# dataset_images/test\score4\12d2167be2791495621982008133752c.png
# dataset_images/test\score4\12d667b70c7d9a4cd20d6be7b3c04a0c.png
# dataset_images/test\score5\12dd190d07bbb3136a522c5372c5a654.png
# dataset_images/test\score4\12e96731201f52ad55ab21fb36d6a428.png
# dataset_images/test\score4\12f5c4b15901e27d30aaf8d56dffa861.png
# dataset_images/test\score4\12f7ce25fa3f67b1638aecbea62d083d.png
# dataset_images/test\score3\13193df5bb908d8027e4a0e51183940c.png
# dataset_images/test\score2\1322dc01915517d88c538f85d5512d8e.png
# dataset_images/test\score4\1343977359bfa1912ba5d07d65897f9f.png
# dataset_images/test\score4\13621e5b1015928529b86882c77b98e9.png
# dataset_images/test\score2\138bfbcc674cc27747e9d871dbd3fe5f.png
# dataset_images/test\score3\139c9b906f2c81d2002f6e40e2e791b9.png
# dataset_images/test\score4\13aa0616ab056ab49ebe549d2737d253.png
# dataset_images/test\score5\13aa099c3dc3f18ac92c85647e524438.png
# dataset_images/test\score5\13ac12ee5a8fe4201a110f8a69d13c35.png
# dataset_images/test\score4\13aecce6419e5f8ad4462b695ae50d29.png
# dataset_images/test\score8\13bb26d628120746dfd3a3c47f83b02e.png
# dataset_images/test\score2\13bec48bcfc2b0f3ee7fded123c82f97.png
# dataset_images/test\score4\13d45f53c43134ce07c6eeb45a30ad1f.png
# dataset_images/test\score3\13df7aa18f80601d445327f218659599.png
# dataset_images/test\score6\13faddcbd18f67ae58b6286265a90a69.png
# dataset_images/test\score4\1409438971b457e03edd353585503f16.png
# dataset_images/test\score5\140e860c53519499fc0605740d2f39f5.png
# dataset_images/test\score4\143855796da87dc34f3b054fc524e19f.png
# dataset_images/test\score1\143a765f42f71c6cd84460902cc83912.png
# dataset_images/test\score5\144ce638108a187c499c420bc051c0bd.png
# dataset_images/test\score3\1471073873fe5bef5f89bf41707f13cc.png
# dataset_images/test\score2\147a8a89c012dfada20704650771d86f.png
# dataset_images/test\score4\147bde93fddeb8265ad8ed7d00791de2.png
# dataset_images/test\score5\147ecc280483720c120faf0ecb8ef701.png
# dataset_images/test\score3\149316cebdcba5749aec0bc5ca87e488.png
# dataset_images/test\score4\14a1fc04981b4cbd384c90b0db3f78ed.png
# dataset_images/test\score4\14fef5e5a843ee949c7f8c0d16420b85.png
# dataset_images/test\score4\150ce62e9c883a57146b9a1fcfa9a1c1.png
# dataset_images/test\score4\15368aa8a2261515c5b09239838fb1a9.png
# dataset_images/test\score3\153bfb3ec1164ec1b176742cd4eb29ed.png
# dataset_images/test\score4\153efd489d89fb3b05257cb0a8eb7d48.png
# dataset_images/test\score3\15790ea9d84802ad1828c2df8292932c.png
# dataset_images/test\score4\1581267f040c217dc01bb82fd9aadc8b.png
# dataset_images/test\score2\1587cc5880ce885a9b6a78338ffa8b37.png
# dataset_images/test\score2\158aaa035796b638ea34970e87c020c1.png
# dataset_images/test\score6\158e8b1491fdcaf0fe52afe415e9cb91.png
# dataset_images/test\score1\159fe2ecd1f1ddcc99df9948a18fb6de.png
# dataset_images/test\score4\15d6f575f720dabc593ddebeb8bec917.png
# dataset_images/test\score5\15de70d686c6357926a1bf99ce9872ad.png
# dataset_images/test\score4\15df8911d81281443ddd8872da84b107.png
# dataset_images/test\score3\15e5ff4d013bc646ba4f3c09b7197025.png
# dataset_images/test\score2\15e97193746bef838f98a0730db84379.png
# dataset_images/test\score5\15f1b9ba67f6d1ab77ebd1870fb23265.png
# dataset_images/test\score3\15f2d0fb163aca3e74d9e6a0e8fd53c0.png
# dataset_images/test\score3\16016faf2cd4546e8acdc63fc12ec226.png
# dataset_images/test\score6\161515d600d424a53702a70f5e184028.png
# dataset_images/test\score3\161adf6daa5895b7c71959dfb8161de3.png
# dataset_images/test\score5\161ea906378805039d27ba513a8302e1.png
# dataset_images/test\score5\164ee956cd43495e5bfd35fe2b25cf5d.png
# dataset_images/test\score5\16549c3d74dd6a387c2910d833d9b97a.png
# dataset_images/test\score3\16565aea3239991eec7a8c8b839e50aa.png
# dataset_images/test\score5\166d89858e477e7fe7a9251f57ff0337.png
# dataset_images/test\score3\167aecb381af7958afbcaa848e41f9ce.png
# dataset_images/test\score2\16a98ad7f701e07ff80b0a3b0b390a78.png
# dataset_images/test\score4\16ad479a6d1a4207f224b125bb3c40dd.png
# dataset_images/test\score2\16b0a53fa5333480197650550317069b.png
# dataset_images/test\score4\16b319c44f353038854298e360cba3cf.png
# dataset_images/test\score3\16b4703bf6869754a53c2cd880ac9a07.png
# dataset_images/test\score3\16b483260d559b108780373362def729.png
# dataset_images/test\score7\16e9d97f5e8b913860694c4dd0e47cb0.png
# dataset_images/test\score4\16ff331d3110eb7d6d6bfee34d80a8a4.png
# dataset_images/test\score4\173ab820059f8d6793f1251f5189dfb2.png
# dataset_images/test\score3\1745dd5651da502c49912b550024058b.png
# dataset_images/test\score6\176831631b211793eb913c8ed2eafd7a.png
# dataset_images/test\score4\1769df10f9eb1d76ef26c04cc806b02f.png
# dataset_images/test\score5\176e2ac9939fc03ca614a6c04610ed0e.png
# dataset_images/test\score7\1775353a3cd4f9fb18e58b7ee7a430c1.png
# dataset_images/test\score5\1778d22169993bacde4f0d8653d6a2d5.png
# dataset_images/test\score4\1779a182104bdb08c190304f26b55096.png
# dataset_images/test\score4\1794951556a251facd3600436072582f.png
# dataset_images/test\score4\179bb808e4fbb6c5b669d962ea2f9b9b.png
# dataset_images/test\score1\17a20ec4413d1d1517c4d108e9215ea4.png
# dataset_images/test\score4\17a5982abd81294e5e1176695b070228.png
# dataset_images/test\score4\17a9a1b302ec91fad91c1364899c7616.png
# dataset_images/test\score4\17b36caa341f88e662a947a742e9dbf6.png
# dataset_images/test\score3\17c8390d4a61b56cfc4a2ed0ceb0e983.png
# dataset_images/test\score5\17d77bd6cdf28304eb0a66456e65fc79.png
# dataset_images/test\score3\17eedfb3cd3674e9d55a3509540e076d.png
# dataset_images/test\score5\17faaa45cd5c0f9d7db8f1cd2c558c89.png
# dataset_images/test\score3\180032a97f5e48dda8eb2b77e93aa53b.png
# dataset_images/test\score3\1807a416442601122293bf11ef55e282.png
# dataset_images/test\score3\181a42d14134343a45acd8e0f0a97ff0.png
# dataset_images/test\score3\181c9e30cf5fa6f679a38a2ba9094507.png
# dataset_images/test\score5\183a5a9aaf981ec1faf3c691dab031a2.png
# dataset_images/test\score4\18515892d7a47a21d243df09c29567ec.png
# dataset_images/test\score3\186de402c32c47e3100d2125780b4181.png
# dataset_images/test\score6\186e6116b3d240d869f51971cdd19615.png
# dataset_images/test\score4\187198bedcab8ce8170bf1568f01c58d.png
# dataset_images/test\score3\18771a6a9c7395b72906c474a11232af.png
# dataset_images/test\score5\1883c7c4741d3bc98c3d62b06ce799f1.png
# dataset_images/test\score5\1889d931bf3091f50b91707d65fb00bd.png
# dataset_images/test\score3\18b08b4adde9b378e24f53977d9879a7.png
# dataset_images/test\score1\18cfbce993f272fcb4ecaaa3aa5853f5.png
# dataset_images/test\score3\18d05442192802b86ec19d11e4bc1ddf.png
# dataset_images/test\score3\18e40f9e7f0c1ec6b153c52a87246344.png
# dataset_images/test\score4\18eca880ddd135602194376a95862ab4.png
# dataset_images/test\score3\190be96996ebb528c1ea58f10a63a041.png
# dataset_images/test\score6\1918f047de9b36a5dcc4216a7bbed926.png
# dataset_images/test\score4\191b26aef5eaa49e3c49b4c7eb3d6468.png
# dataset_images/test\score5\192064491430287f7012f7c42b61ba0c.png
# dataset_images/test\score4\1942b4a1f63ccf6f4bd017c62732f7cd.png
# dataset_images/test\score3\195a5fe7c8e0fc3db74dfc73e6cfbf42.png
# dataset_images/test\score5\195e719d00d7910c55595ec395be85ec.png
# dataset_images/test\score5\196ad3128316745c0ad394f4ac8ce9fd.png
# dataset_images/test\score4\19852a54250d1fa5acda2248fd0b243b.png
# dataset_images/test\score4\1994bec093912c2cc7aaa6f0587a9e7f.png
# dataset_images/test\score2\199b66aa282ea7490bc011a30e31f0a8.png
# dataset_images/test\score4\199c5babda5eeadefd6768bb89f16e6f.png
# dataset_images/test\score3\19a6488ffeb31cdafd8114486d219ba0.png
# dataset_images/test\score4\19ab55cbaa33c6d55bb6f2b3b2e91343.png
# dataset_images/test\score4\19b77c09b8d088ffdc36b1f0a5a65fb2.png
# dataset_images/test\score4\19bb5f997096fd7d24b0130f0134d1ae.png
# dataset_images/test\score4\19c9ad7464c1615a86b2bd5cd08b38ed.png
# dataset_images/test\score5\19d4b1e3a1a1526fdf1c0cf1c2f9a621.png
# dataset_images/test\score3\19d720a4182f61fa559256fec269d73a.png
# dataset_images/test\score4\19ee0f2ec22847cc26a2c36fe0b799e1.png
# dataset_images/test\score5\19ef49e97cdc4b049e366ab7c1330228.png
# dataset_images/test\score5\19fe2b1970339e31ce3abf6b127926ab.png
# dataset_images/test\score5\1a03b8aa979da1b4a9c3b21e296e2cd3.png
# dataset_images/test\score2\1a1a93b9269bf1b80c9b42137e6f8dff.png
# dataset_images/test\score3\1a1cddaa13e17f18a4e8758c36b66eb4.png
# dataset_images/test\score4\1a261e4de89106b081f905dce214c641.png
# dataset_images/test\score5\1a29c252f2d110d19bc5625e5786bb76.png
# dataset_images/test\score4\1a3472826b07110dcf94d152cc7f6e55.png
# dataset_images/test\score3\1a39a1622e8dcb7e720b0baf3e496e4e.png
# dataset_images/test\score2\1a4b60f67cf4954e2652b0b6a23b0474.png
# dataset_images/test\score4\1a4fbac3a6b8465fad15d1d1f5cfef2b.png
# dataset_images/test\score2\1a5e7f57d3794aab386b1f078e90f345.png
# dataset_images/test\score4\1a7053d20bb2c9c9c0d9d26f5b196409.png
# dataset_images/test\score5\1a7ad95b8c2a7621a112a5cd05d7a669.png
# dataset_images/test\score2\1a8816e600c7e552106feece9f509b9b.png
# dataset_images/test\score3\1a8818254262e5a781acbd616b94eedf.png
# dataset_images/test\score5\1a9a8b52ee4ce67f7783a7fe40d6f300.png
# dataset_images/test\score3\1abde93e68777b7bc8feedc77db42836.png
# dataset_images/test\score3\1ac2b6125cd57eea0fac12c607645299.png
# dataset_images/test\score7\1ac2d1593afbd73c9fb9a1a971794beb.png
# dataset_images/test\score5\1ac6913da02aa9c47d2f372c5cb3a28f.png
# dataset_images/test\score6\1ae8a00d231ff30ee0975d586262e740.png
# dataset_images/test\score1\1af4870b0734b8a5ff83adfd9d048121.png
# dataset_images/test\score3\1b2cc63cf47c2e31d18db623e96dc308.png
# dataset_images/test\score4\1b33137ad7ef24d0630b9b496f68ea44.png
# dataset_images/test\score5\1b35443f36660567e6fc38274f8c9e9c.png
# dataset_images/test\score3\1b536c9141ed44ad78c9d39c31d0a7a9.png
# dataset_images/test\score3\1b65bfd27858c8e1bddbe8b4b2f3dc04.png
# dataset_images/test\score4\1b6bee9b02dabf89b22c1b6f91452c72.png
# dataset_images/test\score2\1b9f539c506023768729af4c8b0afba1.png
# dataset_images/test\score7\1bb0c512ff71c717f6917271383844e4.png
# dataset_images/test\score5\1bc1d03658802f1c631ab5616c3be14d.png
# dataset_images/test\score4\1bd2a135bb05ca85042818dfc5d622f8.png
# dataset_images/test\score3\1bde24d5e37503138000a69e4ec90297.png
# dataset_images/test\score4\1beebb43833b41a6edb3bebca8db4921.png
# dataset_images/test\score4\1c00c42aa208b70a3e8583ef005af61e.png
# dataset_images/test\score3\1c11c317f6385b744d2399d0c7d63a24.png
# dataset_images/test\score5\1c138bb10debd7c2a8fa40449c71fed9.png
# dataset_images/test\score3\1c16bc7f64cc7452e689fb34402f502f.png
# dataset_images/test\score8\1c239f5901f59e17b7af78f0d7f436dc.png
# dataset_images/test\score2\1c59509c18a94865d0b6ef9834b93f32.png
# dataset_images/test\score2\1c645080afd86057993e8903855e3be1.png
# dataset_images/test\score1\1c6967f7da3f713b7723b5dc1a96cd8e.png
# dataset_images/test\score5\1c9c0f8593a7b099a8cd43301a425bdd.png
# dataset_images/test\score3\1caab3d1d1beea8d5ee0f32b19e3ec61.png
# dataset_images/test\score2\1cb7dca4cf719dfe55804442d3e5c2e6.png
# dataset_images/test\score2\1cbec97834d086253055fe110309c1a3.png
# dataset_images/test\score3\1cc4b696ae3e04022d43d51c2b195d1f.png
# dataset_images/test\score4\1cca48e8e2c8c9c6e47d60617c905ed4.png
# dataset_images/test\score4\1ccc36af3565710d0e37e6f4cd5d5ff3.png
# dataset_images/test\score3\1ce5615000c3aa1028435268d3f18f05.png
# dataset_images/test\score8\1cf0354e4b7a0d7dac34b16557315046.png
# dataset_images/test\score6\1d0a95a21c4dd39c4cab06403bc954d5.png
# dataset_images/test\score4\1d224c895b0814d230e4ff73746b6f0e.png
# dataset_images/test\score5\1d297b3aa2ab00f631c25cbfb5509fe9.png
# dataset_images/test\score4\1d2c96e5a40aae55c8cbf2eed51bab53.png
# dataset_images/test\score3\1d452b1902b39835e00b8855cebe70f9.png
# dataset_images/test\score4\1d46694e3c48a401c25f1b369921a0a3.png
# dataset_images/test\score5\1d644ec6d21c46be549a241e9d4a9771.png
# dataset_images/test\score5\1d6a4443c74d57cc1c72617027c9ec71.png
# dataset_images/test\score3\1d7ac10edcca630a1195fc5ecfa270f6.png
# dataset_images/test\score7\1d844ae2da11b879da53470902e6b460.png
# dataset_images/test\score6\1d941ff91f40a7989544ac3f35804239.png
# dataset_images/test\score9\1d98f19f209b5e0bfc32a5cc900412c6.png
# dataset_images/test\score3\1ddd804bc73c52aad802aa3c24cc2815.png
# dataset_images/test\score5\1de09a72affe25aa01d71b577ee1369e.png
# dataset_images/test\score5\1de0d988f2e55c1eacf0085728fcd015.png
# dataset_images/test\score5\1de7c16afc0efda851860cb929bfb50f.png
# dataset_images/test\score3\1def012ac2b95848c2725a87e50b26b2.png
# dataset_images/test\score3\1dfe9383bad7c5cf11089797cabf5424.png
# dataset_images/test\score4\1e01194ad9ecabaded94fafbf78d437a.png
# dataset_images/test\score4\1e053c31af5b07fd82f4b7262fde997f.png
# dataset_images/test\score2\1e184e4aca8fd551f3bf0d11da3c2e8f.png
# dataset_images/test\score6\1e2e98834796630ef24e0fb871a21155.png
# dataset_images/test\score4\1e3ada85fda35249e7c8320be1f58e0f.png
# dataset_images/test\score5\1e47535dca0c3f2296447c26d8d1c99c.png
# dataset_images/test\score4\1e53f8ae1a028ff5f2db16e4b5223ba1.png
# dataset_images/test\score4\1e8996389008871bdab53e8fa08ae8db.png
# dataset_images/test\score7\1e980a47b6544d779a39369967797741.png
# dataset_images/test\score2\1eb0dec9ea84aaa51e3c34bc7346153a.png
# dataset_images/test\score3\1eb80aef1647e8fab6b363cb7732a130.png
# dataset_images/test\score4\1ec02437caef1bff4c02e6b262683e45.png
# dataset_images/test\score5\1ed0484ea0317520f5a6f3af230455b8.png
# dataset_images/test\score5\1ed69bdaff3e77e5b753285a11e6c4b7.png
# dataset_images/test\score4\1edc362eb30a39fd0dbe747b93d1a1c5.png
# dataset_images/test\score4\1ee64dfc1730218a5a9ec197944512f6.png
# dataset_images/test\score3\1ef50ec5bcd1ec8038aeee9846c58d03.png
# dataset_images/test\score4\1efa79f2c339f4f5c0a8c65a3ad9c269.png
# dataset_images/test\score3\1efb344729d812792e49f8e491ea408f.png
# dataset_images/test\score3\1f01e66f0c5186b75114a22d7545b269.png
# dataset_images/test\score5\1f0b8846ed093d8580d2d18eb083377b.png
# dataset_images/test\score5\1f468e4a155fea67f71c6b15e903125f.png
# dataset_images/test\score5\1f4895eccf21d1507b2044a921d506a8.png
# dataset_images/test\score5\1f50e766d30d701e74f06dc09ca81501.png
# dataset_images/test\score4\1f733a48f03af498490d8b8d11d57411.png
# dataset_images/test\score4\1f850139c5a0303561b70e67d76f6243.png
# dataset_images/test\score6\1f93724c3ed063e98a9a2460d28a6e52.png
# dataset_images/test\score4\1fb4562529b84dc65cca2c119aea6b2c.png
# dataset_images/test\score3\1fc8e9e8a63f8ff522c05cc99eede804.png
# dataset_images/test\score7\1fd427905c83d408807bd589289d8c36.png
# dataset_images/test\score2\1fdb2ec9662f2136f0585cba289c0770.png
# dataset_images/test\score4\1fdf85705bef0edbf2cf8eee5bd1a9b0.png
# dataset_images/test\score1\1fe08df23d57e53c738c9ad98449c5ac.png
# dataset_images/test\score2\1fe6dec11d81e52519bca0ac15a817fd.png
# dataset_images/test\score3\1ff2698045bb0917eef2c0372921cb12.png
# dataset_images/test\score6\1fff2ee2f061d7cdc669ed514d7da8e6.png
# dataset_images/test\score4\200e839d0fe4fb1878ac6514c153e86d.png
# dataset_images/test\score5\20465ccd00efc4a09527f56b4be41838.png
# dataset_images/test\score5\2055a764b034a2b67bca09c79b19d8d5.png
# dataset_images/test\score4\20723d26d2d2925d368b217bc532f1b8.png
# dataset_images/test\score6\2092cd77086fe9ed839aa52d3d2911a0.png
# dataset_images/test\score4\20bf9e61270456cc6610fff4ea67bb9c.png
# dataset_images/test\score0\20cb25a79964c2a1a819ae21356c7b2f.png
# dataset_images/test\score4\20d1a7d46651cf7c6af073bdcc2b830f.png
# dataset_images/test\score4\20e22c191e683cad6af17e1c73b6269c.png
# dataset_images/test\score5\2117a37a4debd97daf9ddc587ab81ddf.png
# dataset_images/test\score3\212ee27856d5b1a331575e61a746133e.png
# dataset_images/test\score4\2138b8df4bbe9fdb4e4435b652a3d21d.png
# dataset_images/test\score4\214577918b95a8a999189facaf62bdca.png
# dataset_images/test\score6\214838c2de3e51040d97ca570af65732.png
# dataset_images/test\score4\215228b4e437892287016ae9e13905af.png
# dataset_images/test\score5\215c25d1571d6a13c4cbeb1ee81a847c.png
# dataset_images/test\score2\2171c28920689bb55d7fd0a7500402a7.png
# dataset_images/test\score4\2199896a4bafae616bef4e8400473700.png
# dataset_images/test\score2\21abbb1111e772809a631c34e3c60bad.png
# dataset_images/test\score1\21c60bcc6e6a9fddaf26fce644e082ae.png
# dataset_images/test\score5\21cb89aa8efa3abbb9cb7a4d216c82a2.png
# dataset_images/test\score4\21d2f08d0a3bdebb575cfdb95b7afc56.png
# dataset_images/test\score6\21da8b8e78a3ab511347f8ff684b7134.png
# dataset_images/test\score3\21faa1dd82b984553b7dcff7245217ca.png
# dataset_images/test\score6\21ff05f03d8789826ed19f321ecd3686.png
# dataset_images/test\score7\220959795b8a6397ed55b90965c1379d.png
# dataset_images/test\score5\2226a9b7c9711174d409a320246ad47f.png
# dataset_images/test\score6\225829fe9e56464874e6fa74cad6ad28.png
# dataset_images/test\score4\226546b8f2e98c57e0cfd26ef7b0eb3e.png
# dataset_images/test\score6\227c3ccd8dd74fd68a0fdadac9be5a3b.png
# dataset_images/test\score4\22829442469fb589bc5683b11156a314.png
# dataset_images/test\score4\22b418a8e45ae7cb3d1310f01ce7f763.png
# dataset_images/test\score4\22bb8ae520411a000b6c03c8e3008031.png
# dataset_images/test\score6\22c5426d689db4aba91b6cc23df4fafe.png
# dataset_images/test\score4\22d52b7dbcc5232f0698c1f3f67816cb.png
# dataset_images/test\score3\22df4d0e34f410409ddf069ea66c46ef.png
# dataset_images/test\score4\22e1e6385a6818caa981eca7a0a00703.png
# dataset_images/test\score4\22e31f07df17ff739a3d670f22f91393.png
# dataset_images/test\score6\22e42860ae027b6e1ddf29b40ca62fff.png
# dataset_images/test\score3\22e44fb5e11f02cb428eb3557f8f542e.png
# dataset_images/test\score4\2318663d893257323e248931b933af9b.png
# dataset_images/test\score4\231dda039dcf1a61f00c80a9c731595d.png
# dataset_images/test\score3\2330a48d68448b07501a071aac9179c9.png
# dataset_images/test\score5\233d773218bc930748ebb877c0e0ad48.png
# dataset_images/test\score4\233eca896794e84bfb9af98724678bde.png
# dataset_images/test\score3\2375dc64f484613dda3c8a7ce9f2d712.png
# dataset_images/test\score4\2385fb12d199926f7b54b33fc2d7850a.png
# dataset_images/test\score3\238d333567766458d25137485bf45a19.png
# dataset_images/test\score2\239c75e65e8bcd0812d98c30ca7c0c16.png
# dataset_images/test\score3\239e8ce460f7865b38bdfd8900d92b55.png
# dataset_images/test\score3\23a492cb695af894a3f6b93485a7db3b.png
# dataset_images/test\score4\23bc7defc63d77c0e64b68821f5f2b69.png
# dataset_images/test\score3\23decdb87b9b3c932733f35e0c2b3b08.png
# dataset_images/test\score5\23f72b8598ad4087c87060cf7d46041d.png
# dataset_images/test\score5\2401e36ee5a5930270a091f89b1ab98c.png
# dataset_images/test\score4\241f4b9c63e444afa2327325019ddc7c.png
# dataset_images/test\score1\245540469701fe4044fe53b85e5d93ab.png
# dataset_images/test\score3\2455fec609d21cbcf6ecf440f51c8b3f.png
# dataset_images/test\score5\2461a83398fea4f058c27bdf817ddf9b.png
# dataset_images/test\score4\246e5224b892d189ab1dc75f7f9e1685.png
# dataset_images/test\score4\247beaf71109099e3906a41e7c819e03.png
# dataset_images/test\score4\247c4737729e8680d869d1bc27f505e4.png
# dataset_images/test\score3\249163abf6f27c11808c351c380f08a0.png
# dataset_images/test\score5\24a078c4a9087f3002459acdf39ac841.png
# dataset_images/test\score5\24afc1a35672a3f947368631f9e773ae.png
# dataset_images/test\score5\24beafb7f4723d04d123cfe802197a04.png
# dataset_images/test\score3\24c82ab3280eb00fcd1dba2ce4a11df7.png
# dataset_images/test\score6\24cff6832be0a24576724f90ed8601a4.png
# dataset_images/test\score4\250217e21a154acf08b0c22c1fbb72c5.png
# dataset_images/test\score5\2504adf6bec0bfa472f726c0e66f0c03.png
# dataset_images/test\score3\251bf66081fedd151b321fa3642044b2.png
# dataset_images/test\score6\252e2f521013adc7c02ab3ee443bb0ff.png
# dataset_images/test\score4\252fce40c96c1266f703c6f4e19bcafe.png
# dataset_images/test\score6\253590543425122d0909061dfa3f9752.png
# dataset_images/test\score3\2554db3966a42afdabc490b7869b8fdc.png
# dataset_images/test\score3\256d96de3ba9b9b8113b9471db0eb562.png
# dataset_images/test\score3\2578d28043da63990e412886bee238eb.png
# dataset_images/test\score5\25a128117ab7a3eb47feef43b22c80de.png
# dataset_images/test\score4\25b3d0ae7f1ad709f306571bce7cf299.png
# dataset_images/test\score3\25c7908af45a28644bf77c27af178f84.png
# dataset_images/test\score5\25cc2310d584a6e3a0ee0ed820dd1372.png
# dataset_images/test\score5\25ecd334d8be2676bb7e6d287fb914c5.png
# dataset_images/test\score4\25f33878405421c2d2bfe79f81f17d1f.png
# dataset_images/test\score5\2606d38eaabb947d6df051920f297c3a.png
# dataset_images/test\score4\260c51cbc131889aaa251596ca9516f5.png
# dataset_images/test\score6\2613ff104228f607a2c08707dd732305.png
# dataset_images/test\score5\26480c2bd904e456a0d49548e2c53a8f.png
# dataset_images/test\score9\2679edbe2a35e56591139c6bb11b1652.png
# dataset_images/test\score4\2683e0f8734e4c33bab486fe80e82787.png
# dataset_images/test\score3\269fa8bcfc1318548853582a37c5f70d.png
# dataset_images/test\score4\26a1c13474d87b1f1669655680cf6700.png
# dataset_images/test\score3\26acf5653f07b89703e24b50881dc26c.png
# dataset_images/test\score5\26b083027f2a59270d71a6212dc1024f.png
# dataset_images/test\score4\26bf6edc131a0d2976740bd298c00f7a.png
# dataset_images/test\score5\26cccda6b567df226196d95d8c1b1b03.png
# dataset_images/test\score5\26d20ae4d1702001378051fe73b72add.png
# dataset_images/test\score3\26d25a91f50d6d73d3b6edc9ffc8b2f2.png
# dataset_images/test\score5\26d4c062c1c7acdda5e737e7e2db84e4.png
# dataset_images/test\score5\26da829ba1a2db5fa999d74b0470e080.png
# dataset_images/test\score2\271b5ba184a748f5b14d517b833ea8a9.png
# dataset_images/test\score5\271d9843e97c0a67c7c50afb84c79c77.png
# dataset_images/test\score3\27351bac7b40af5adfda535521845503.png
# dataset_images/test\score4\27365e73223d093e84ec60314eab8e5f.png
# dataset_images/test\score5\2742d74748142fbc77fc10f1d98c15a3.png
# dataset_images/test\score2\2746da21d31a7cbabe12aa05204e1e3c.png
# dataset_images/test\score2\274f334b73568dc61b7a1622d5767f2b.png
# dataset_images/test\score4\2757d39f33761559b52eb8bc3be9471d.png
# dataset_images/test\score3\27705500608109f720dd0ca3f5ee6755.png
# dataset_images/test\score5\278dc3acae66bc9229b1ee60febe9732.png
# dataset_images/test\score4\2792b30704429130a74ea5ad2631a7a3.png
# dataset_images/test\score4\27988a4c86c0ebd3d65167d41a70a02f.png
# dataset_images/test\score1\27af7c27c34930e56081e7d59fb43efb.png
# dataset_images/test\score3\27be33ab5c74fc459a84e1f99f49ce99.png
# dataset_images/test\score3\27ccf7db2edc03f2601fb3614d896d7c.png
# dataset_images/test\score5\28387119694b7901a0489982da8aa6f4.png
# dataset_images/test\score4\2843060571a3e166c966df827d26a73e.png
# dataset_images/test\score5\284bb9cc171ed6f7104c9b3810b573a5.png
# dataset_images/test\score5\28508aa56c79498bcc6c6733c0cd03c3.png
# dataset_images/test\score7\28549af8b5e1695ef23459c9a4ba9ad8.png
# dataset_images/test\score3\28619168af8fe25e9af856b4dea822ad.png
# dataset_images/test\score2\287d18558a60e48323c9b6634b768759.png
# dataset_images/test\score3\28998c8079008dd5fc523951afcfdd32.png
# dataset_images/test\score3\28a13781045025a2ad36e4430d6810c6.png
# dataset_images/test\score2\28acaa0ab04b037491dd3e99d4d4dcbc.png
# dataset_images/test\score4\28c2a8328eb8b9579e62126f4e85ec2c.png
# dataset_images/test\score4\28c55ec6913d0509695e0a402d1d5358.png
# dataset_images/test\score3\28cc67684338fa1929715a975fd7d9bc.png
# dataset_images/test\score5\28da2179e97bba3b303fd33de53a2cea.png
# dataset_images/test\score5\28e2cb147936c49643921043cb1bf00f.png
# dataset_images/test\score4\28ef686c0564a080c2dc8b7484b79c97.png
# dataset_images/test\score4\28f4e0e2eeacf3ee2d86148c02920826.png
# dataset_images/test\score4\28f51c800567462474125b1c6ac4d7c0.png
# dataset_images/test\score5\28fa2b4fc6b6aa3c09fd8ee4287b7d7d.png
# dataset_images/test\score3\2924675507d84403f4cfbd93d57908a2.png
# dataset_images/test\score3\29337397c55964e4106e3602a2a22b5e.png
# dataset_images/test\score4\293c6b7a5b2932733a79b800ef42a7fb.png
# dataset_images/test\score7\294ab0cc237f9e63f1a1206936b1ca97.png
# dataset_images/test\score3\294e5ee0430b2947bbd4bc3a2a5dc7f7.png
# dataset_images/test\score3\296d1e7d07dcbc6888e88da343d66681.png
# dataset_images/test\score4\297bb23b4adef3abee17c576aaebba4c.png
# dataset_images/test\score4\29b42e89bba12dc1b3fe3e7cf94b28db.png
# dataset_images/test\score4\29c33073870973f7490d3d52ac205c7e.png
# dataset_images/test\score4\29c6cdfd85b329f0d1e00f10d805b180.png
# dataset_images/test\score2\29da634a52768e3eaae4ee71b16e1acf.png
# dataset_images/test\score6\29ed66619a6b76dfa5bb35a6eb0db7c2.png
# dataset_images/test\score4\2a157a85332bd0ee1ee4b1780b684071.png
# dataset_images/test\score4\2a23634c7307a76b9d263042f3f0d961.png
# dataset_images/test\score3\2a300f543fb93bf19eb9b99b12f3ef7a.png
# dataset_images/test\score4\2a39721746e5df9f7742a89f6dba37a5.png
# dataset_images/test\score5\2a44fdb6cf7a90147e3df3bc8934618c.png
# dataset_images/test\score5\2a562cb85ca393f5f065b6228fc12c37.png
# dataset_images/test\score5\2a8053372d85ad17a9ad52a1a8278984.png
# dataset_images/test\score4\2a8d99d4cce91fdb881b886daf523313.png
# dataset_images/test\score5\2aa526045db8493cdfa8e1d8b71c780c.png
# dataset_images/test\score2\2ab3aaf5960e0f52d251e44c470b4634.png
# dataset_images/test\score3\2ac884d2c97adc0d013de06a9f91210d.png
# dataset_images/test\score5\2aedb6c7c446f7a355de2e66a0fbd7c2.png
# dataset_images/test\score4\2af1553c2bea383db94d5a078f41e0bd.png
# dataset_images/test\score6\2b56b212b7a7f2c3cfb3560aa114fa39.png
# dataset_images/test\score4\2b5b2882474a9d07866c6d96f49b407f.png
# dataset_images/test\score3\2b7af126d802c784f9acbb6f8b3625c3.png
# dataset_images/test\score3\2b85023b7d02f62952a98f9713c0f095.png
# dataset_images/test\score3\2b874ec40e501036dcf27250abc0481c.png
# dataset_images/test\score4\2b8e8a0b66226f28519b1bf3f7a5d2fe.png
# dataset_images/test\score6\2baa17f0bda3f85a6387298d8cba019f.png
# dataset_images/test\score4\2bc304c29b1117749dfbd3caae495cd5.png
# dataset_images/test\score4\2bc840f00540fc363095255f61505d9b.png
# dataset_images/test\score3\2be71d94d292e3767044921373820fc8.png
# dataset_images/test\score3\2bfc5443cdbc6877829d6a58c47b9108.png
# dataset_images/test\score4\2bfc7d7d4da3f01653b57ad57aebc463.png
# dataset_images/test\score5\2c370ea12025d9294284700d6665f0fc.png
# dataset_images/test\score3\2c37f3e244ecdd57e99dcbf9e29438e3.png
# dataset_images/test\score4\2c4745145005a395b61c550acdb843d4.png
# dataset_images/test\score6\2c4d0d37df068c7a7724568133077201.png
# dataset_images/test\score2\2c5df20c3e6c84210095bbbd522e4d82.png
# dataset_images/test\score3\2c608bfe92b75c54834d592df3072619.png
# dataset_images/test\score4\2c659524d63e800b650254d8e1445b98.png
# dataset_images/test\score5\2c6b6069f1e8ef87242a40bf13c51323.png
# dataset_images/test\score5\2c86b7f1246589888f350c7fa2ca0994.png
# dataset_images/test\score3\2ca86b4d72557ffe002e89a8dc82f2e7.png
# dataset_images/test\score5\2cb7c1b82f1fff5376441fad8a2ba3ce.png
# dataset_images/test\score5\2cc4c153837e71127fec5465ad4ae2d2.png
# dataset_images/test\score5\2cce1761b682b1ca54361d1d2a69a33b.png
# dataset_images/test\score3\2ceff3e1fc8be207d989ee264f82a57d.png
# dataset_images/test\score3\2cf1e897f06daa8e71de41269189a9cb.png
# dataset_images/test\score4\2cf2af047c7efdf4c1da404e751779ee.png
# dataset_images/test\score6\2cf50f560e9df14600521aeccc04a14a.png
# dataset_images/test\score3\2d02acf79ff6a76cdc428cbf69b10883.png
# dataset_images/test\score3\2d0cdbdd57e757a7f1ce3d830a337640.png
# dataset_images/test\score3\2d23f3695fcbf40b1c65f7bebcab3d30.png
# dataset_images/test\score4\2d2f3084f08db4d7ac79bb3ec613219f.png
# dataset_images/test\score2\2d318def14c85af01117bfe87fc23912.png
# dataset_images/test\score3\2d3b12764bba20c5afbba4972532d20d.png
# dataset_images/test\score4\2d47b25fb09f07fc136940c2e89c26f1.png
# dataset_images/test\score4\2d52d7ceb275cc753b39e0d1a7f37387.png
# dataset_images/test\score3\2d6001a6b289224becb3b4db1783ba0a.png
# dataset_images/test\score5\2d973c9cfb9cc97a25c6ab85980447a0.png
# dataset_images/test\score5\2d99bed1b363e982c9427375699f25a0.png
# dataset_images/test\score4\2da25c5fb782e890646e95bce52e9658.png
# dataset_images/test\score4\2dd2a415d59190d1f7122ca136b828a8.png
# dataset_images/test\score5\2dee2fffb31fd241b9a32bed74c4a5ab.png
# dataset_images/test\score4\2df1da0726c9676c88df7636ec757fb5.png
# dataset_images/test\score4\2df63e1c6b75e6ab494a41a9fed76900.png
# dataset_images/test\score6\2df88b976b0485d21adc36fb76ca8bca.png
# dataset_images/test\score3\2dfd8df409c69396792fdbb3071a5281.png
# dataset_images/test\score4\2dfe5bb7357e8a205d0e107fdbebc9f5.png
# dataset_images/test\score3\2e18263bfe306a755da33a8f54047118.png
# dataset_images/test\score3\2e19fb7bd0e278ab1ba5f9264e5a7afa.png
# dataset_images/test\score3\2e1def3a13a370ca93f9acfd0de6fa5c.png
# dataset_images/test\score3\2e29087ee91fb159f3d8722da337fc66.png
# dataset_images/test\score4\2e3215269528fa32732195f806dfae0c.png
# dataset_images/test\score2\2e577f2e6434836dcc65cfc9b8467f6c.png
# dataset_images/test\score4\2e8a4627928aa1121e011cc98b2bbc9b.png
# dataset_images/test\score5\2eb4b43cc036e993a96c71af8b462c37.png
# dataset_images/test\score4\2eb557a72f751aa2917ee66c8dd0ec59.png
# dataset_images/test\score6\2ebb67765a4fb1086f50f4d2ed803f20.png
# dataset_images/test\score3\2ebbbb6eaf6fbebd73f3e8d7c49c7214.png
# dataset_images/test\score5\2ecdbe46397053274679a5b6ec4953c3.png
# dataset_images/test\score5\2ee52ce1188685d9abaa6230ec25123f.png
# dataset_images/test\score3\2efd5d164b4fc5b2dd9e556d3d5b498a.png
# dataset_images/test\score4\2f09642a66201eb021379e1b03bedf37.png
# dataset_images/test\score3\2f1aabe70404f9328f0996b83e26ad34.png
# dataset_images/test\score4\2f21cac43bd8b8545ddf74527a9417c1.png
# dataset_images/test\score5\2f2686f4e8c525ff996e99650d60d3a5.png
# dataset_images/test\score3\2f2d3e7261ae168d4a53dea350e23248.png
# dataset_images/test\score3\2f4e588c58a464217700073ea324eeb6.png
# dataset_images/test\score5\2f5b5f375d6299b761c3e4f77f6f8470.png
# dataset_images/test\score6\2f798d63f79c7068b475015105146519.png
# dataset_images/test\score4\2f9ac675910a7f21a397e14430c6dc19.png
# dataset_images/test\score4\2fa612abc41449cd3e89dce52c8378af.png
# dataset_images/test\score3\2fa7c70937d5760898bc71ca24736a7d.png
# dataset_images/test\score4\2fab52db2a7c715125a68f4884b8ff02.png
# dataset_images/test\score4\2fac65cf804a99b12fc042d0c050b691.png
# dataset_images/test\score4\2fce797b14ef4cf2cb5867f6a6aa9619.png
# dataset_images/test\score2\2fd4fd78055ba90e6f1edd69fc4d6133.png
# dataset_images/test\score3\2fde89e2b32b4d7b5dee80d8ce8eb72f.png
# dataset_images/test\score4\2fdeb91335e6eae6598496140fc1954e.png
# ...
# dataset_images/test\score4\f068f48738f92b1d895029db7bc9f124.png
# dataset_images/test\score5\f068fe5812d8eca3bacd3b5be201b5f4.png
# dataset_images/test\score4\f085b6b77b7dcccbdc2dcedce906297d.png
# dataset_images/test\score3\f08e0be7dbdd8ac390655de1d5aa4821.png
# dataset_images/test\score5\f0907be87af164b9b78105b42bf96cbf.png
# dataset_images/test\score3\f095983130ce41a6afc7d534e8d3c26b.png
# dataset_images/test\score2\f097543e84ec92ddd8b5e1804210d9fb.png
# dataset_images/test\score4\f0b111f1bacf6894a1679900b10175c4.png
# dataset_images/test\score5\f0bbe39ff58753767566b10efd6d9033.png
# dataset_images/test\score3\f0c31929a42c699364b888f199fdee70.png
# dataset_images/test\score3\f0df43e83090805c434a303151e20bb9.png
# dataset_images/test\score2\f0e3cac421d671ece310f0ba6701b673.png
# dataset_images/test\score5\f0f2f56d46c3d361c088434665a6ce73.png
# dataset_images/test\score5\f0f30341b824303d4ad38fb7d4617bf3.png
# dataset_images/test\score4\f0f335532aa2ce2652f8651ab37ad6cc.png
# dataset_images/test\score3\f1085d546cd688ee3382f7b9af50a7b3.png
# dataset_images/test\score6\f118cc80348e393ed812bc1c3ff46f56.png
# dataset_images/test\score5\f11f316a509b178dccc4fb90eca74867.png
# dataset_images/test\score4\f127b47859294d8ed19c4c609022d01e.png
# dataset_images/test\score6\f12d8921e7493bf2def3760d8b01da92.png
# dataset_images/test\score5\f1514b89ba66e9aa4dbd9b30b0b2b6eb.png
# dataset_images/test\score3\f1637b4ee8003252a374da7fa2c83f55.png
# dataset_images/test\score5\f172bea511e6ac1cf53e8c3cde039513.png
# dataset_images/test\score8\f17ceea32dfe6f5b5491b92b68faf262.png
# dataset_images/test\score6\f18fc27f92817d4a93bc6ff650835a99.png
# dataset_images/test\score4\f1b3c99bbf6f2391c0eae255e57db453.png
# dataset_images/test\score4\f204c74e9b4664e7ed2524622e4b7774.png
# dataset_images/test\score5\f223d99c554796a1f903bf83bc2e8928.png
# dataset_images/test\score3\f22e20ec6daf79d5999efc93f953d4c5.png
# dataset_images/test\score5\f23d5c12ac7c3a856fa02723fd73bf91.png
# dataset_images/test\score6\f243d67197a72e826664327c44d9fae8.png
# dataset_images/test\score5\f24acbacb3688806bfb30708b2cc8a1e.png
# dataset_images/test\score6\f250279b7f098d20cbb038894589b9e4.png
# dataset_images/test\score2\f252cdd19ea396ee83b5b820e51645c7.png
# dataset_images/test\score1\f27a7a890a33370c3f46515ed42fcf4e.png
# dataset_images/test\score3\f28061429403d65f992aa68cb548b4e1.png
# dataset_images/test\score5\f295cb3d6317c41f7095ada1fd25ea51.png
# dataset_images/test\score4\f29e0506d500fe25a752bdb24fbe2f35.png
# dataset_images/test\score3\f29fd3e44210626fdc72db446d36175a.png
# dataset_images/test\score4\f2a9d8f018154c244881646539673811.png
# dataset_images/test\score3\f2ad48b06962b62b131ab48686e15563.png
# dataset_images/test\score4\f2b016fed26b4c857cb77bd44108515f.png
# dataset_images/test\score4\f2b9833c87abd36443b6ca2437d57012.png
# dataset_images/test\score5\f2c1e2bffb4c8d8716c7309c90b58399.png
# dataset_images/test\score2\f2e3758d20561ae8868e9412603e7f3e.png
# dataset_images/test\score3\f308b78d096c497a48d37d86644ccbdc.png
# dataset_images/test\score3\f30e9a7949da54d9625c60ddbac09c92.png
# dataset_images/test\score3\f3323f329a9445985c29d36ee983cbf3.png
# dataset_images/test\score3\f345ce940ce90745192f40cf23f62159.png
# dataset_images/test\score3\f3576b34494aa1be3b568bafe3c0e649.png
# dataset_images/test\score4\f3719b1b4ec99327808f5384944d7bc4.png
# dataset_images/test\score6\f37be102bb2af1aaa06d58a1e57667d3.png
# dataset_images/test\score6\f39183a93ce044c76b1329a8157273da.png
# dataset_images/test\score1\f395f29b76cd1e0d4bc6e06ba213f376.png
# dataset_images/test\score4\f3bc2cf294f0bc7dcc6080cf5a69b7ad.png
# dataset_images/test\score4\f3c38e91d9588c152f3d84e7624b09b8.png
# dataset_images/test\score4\f3cbed9ca218c02062588a61b11d0565.png
# dataset_images/test\score3\f3e1e7235c59b7f201604fb58093fdab.png
# dataset_images/test\score2\f3f1766039d1ca3cac40a1baf7be9f3c.png
# dataset_images/test\score5\f3f515548f90d944c8814c5265935fc9.png
# dataset_images/test\score5\f403e66dac3bfb1b7125340c9b1e9f3c.png
# dataset_images/test\score4\f40845bdd565358956b664c480bb2c2e.png
# dataset_images/test\score3\f420bb2274f02f39bb9176bbe81f70f8.png
# dataset_images/test\score3\f42cbf50d60ccb12dc5682320479a41e.png
# dataset_images/test\score5\f42f265e8b0b53d2d01009e767466a07.png
# dataset_images/test\score2\f4328678aaf774aa5f653e02027f9735.png
# dataset_images/test\score3\f4380fc8f3c434d1a1721a6dd210ab1c.png
# dataset_images/test\score4\f43c3e86ba3343ddf20c9520c2e570a1.png
# dataset_images/test\score3\f44139c5b48d6360eb0c41b09e3884de.png
# dataset_images/test\score2\f446b6001e50212f722ed1c3bdf0bfb4.png
# dataset_images/test\score5\f450e9f0e9921b04f4d2fb284c17610b.png
# dataset_images/test\score6\f4541d0d9db71a2b67244d9cb27d2535.png
# dataset_images/test\score3\f455bb3bd1cbf4b4164937315fcb1897.png
# dataset_images/test\score4\f48d54e3d40dfc67475ede7cfc25b016.png
# dataset_images/test\score5\f4aa35992336d78180c4733b259f1211.png
# dataset_images/test\score5\f4aa51f1a4796079a174f5eb3b53ecac.png
# dataset_images/test\score3\f4ae0bb12c0758c0f9a052f3b556b11a.png
# dataset_images/test\score3\f4bcfb110b3e6720fa3d2cc67dd170d9.png
# dataset_images/test\score4\f4c94454d91066ea7c291b7faa030297.png
# dataset_images/test\score5\f4cfca924f4d6174dc7112b42bf91ed2.png
# dataset_images/test\score4\f4d1907a48c24331d656385dca26e02e.png
# dataset_images/test\score4\f4d6d38f87bdeea42ac5836599e286c3.png
# dataset_images/test\score5\f4da779ed5bed93ed990612a50f35051.png
# dataset_images/test\score7\f515ca1263ca650272776a2d353cdac1.png
# dataset_images/test\score6\f526f4352589988910ad3449d7dca239.png
# dataset_images/test\score5\f52978ffb28423625c110acdb78a6a5a.png
# dataset_images/test\score3\f52bb3d8882fc13e6e725debbfc9606b.png
# dataset_images/test\score2\f56550d562a09c4667a5d824712488bd.png
# dataset_images/test\score3\f568af2e7f4b9c9b839bd93396fa40d1.png
# dataset_images/test\score3\f57b492443e116ab90d0adaf48c85408.png
# dataset_images/test\score3\f587d4ef94ef526e45335e377e57dd8c.png
# dataset_images/test\score4\f58b12ce4091eb559229826c3b9ade42.png
# dataset_images/test\score5\f5afdbbd0b7d900a4709da76653cf059.png
# dataset_images/test\score7\f5b80ac34d274f9b4288a7fb12d884cc.png
# dataset_images/test\score3\f5d630a6de8820c0fc5415066e663924.png
# dataset_images/test\score4\f5f90277b4e15e50e8c6fd5bb93f5e4e.png
# dataset_images/test\score5\f61108078ee745347faf24c0929e299c.png
# dataset_images/test\score4\f611cf74fcfbe40087f7b7bda2c48f00.png
# dataset_images/test\score4\f63c636da1f40bb0180b4520d6164eb3.png
# dataset_images/test\score4\f644039ef591dac79cb73c336bad564f.png
# dataset_images/test\score4\f656a79d24c49578adaa135f593c34df.png
# dataset_images/test\score3\f673447000e96d23e0b698e5d83acf29.png
# dataset_images/test\score4\f683388faa90686bce20bfe56272d1fa.png
# dataset_images/test\score4\f6839f16a2367953581fe73f7c1da254.png
# dataset_images/test\score4\f6947c2df9e5af01cf4eb4e81fd4ba4e.png
# dataset_images/test\score4\f69fd939c49170c157b8c69622745240.png
# dataset_images/test\score2\f6b1fef994a1ddd0fefcaef31eaf594e.png
# dataset_images/test\score2\f6b37312569c2dfbf8bc96f195d820f1.png
# dataset_images/test\score3\f6bcc841167fb946451fdb8963d01c86.png
# dataset_images/test\score4\f6ce6c0e630faa3e9d067b81ac0f2264.png
# dataset_images/test\score4\f6e7ef360a0b8eccbfe852198ac6b729.png
# dataset_images/test\score4\f6ef4f33bfe0c4ab1c743284495a52ec.png
# dataset_images/test\score4\f6fe3a26e4002cbf767b35f6ac591f12.png
# dataset_images/test\score2\f6ff861d1284e9f32f857a3b9ac4ca1c.png
# dataset_images/test\score3\f71f860919f91e51fba500743651a8f0.png
# dataset_images/test\score5\f73e4590c8a88ed26273180715f4d4cc.png
# dataset_images/test\score4\f73ef1b24542a45d79381633e164c1e8.png
# dataset_images/test\score3\f754f9c548470da3bad6ba7a66b958d9.png
# dataset_images/test\score5\f757039a5c4f03b6140c1460eebae424.png
# dataset_images/test\score0\f770c9a92d68216a2f8dd63cee04ed36.png
# dataset_images/test\score3\f77a5f0a82a760af3ee71b76d6ccb8b8.png
# dataset_images/test\score4\f7b41664cfe34cf53d4bb153da59d73a.png
# dataset_images/test\score3\f7bcc9ba746192b8dc2d5e529457eaff.png
# dataset_images/test\score4\f7bf5bb183f6e11643b0eeadc4612736.png
# dataset_images/test\score6\f7c0afec56b7895e64e8171573574fd7.png
# dataset_images/test\score4\f7c1da952fab1c921331611479b2bc9e.png
# dataset_images/test\score6\f81cc72d87cf87b1b649274e4a75df43.png
# dataset_images/test\score3\f81e0566a8b31ae77e839a7a51299515.png
# dataset_images/test\score5\f827ea355fa5321995fccb1d80f359a8.png
# dataset_images/test\score4\f83b39634d3ce77011867e47ae03c44f.png
# dataset_images/test\score6\f843125111309c84038485e8daf191fd.png
# dataset_images/test\score5\f8528e7caa862fc2d02640f899015ae7.png
# dataset_images/test\score8\f86492bdf4870ffd8e05c01945bb87b4.png
# dataset_images/test\score6\f877b8494f546cc79ff0a2ff0bc7d6e3.png
# dataset_images/test\score5\f88b5a190dade7bf7858b743bc01d051.png
# dataset_images/test\score5\f89052f9d033908c93b1f701a0e454d1.png
# dataset_images/test\score3\f892596ebbfe94a7c6a2faddeda0f377.png
# dataset_images/test\score4\f8b74add4005950402b84372eca8cc9d.png
# dataset_images/test\score5\f8cd6f6be4735079b360b192b5c75fa2.png
# dataset_images/test\score4\f8d3af3f8976f57b591425bccab8793d.png
# dataset_images/test\score3\f8dfdc900d9d9510cb55ff4576e20a59.png
# dataset_images/test\score4\f8f5bcf8adf99e5fed7bb384913be976.png
# dataset_images/test\score5\f8f7697e54b2f5ba3f8129ddd31d35d0.png
# dataset_images/test\score3\f8f9fb244d0d5ac0df1c61bb1c68ec42.png
# dataset_images/test\score3\f8fd394d39edfe370b5e6217f9e9c361.png
# dataset_images/test\score3\f903be7f15cc8c0e309bafc86165decd.png
# dataset_images/test\score4\f91c7fbfc67a3e37a055e7fc9d42a530.png
# dataset_images/test\score5\f92263854c8fa47ef588a926468e743a.png
# dataset_images/test\score5\f93bae7d47f8ac74456dd5b4467853c9.png
# dataset_images/test\score5\f94d29b02644db4db119313480f26734.png
# dataset_images/test\score4\f95dd295dc426be94ef0cd120e35e806.png
# dataset_images/test\score3\f97b327e53ebaaf3ca6f13ffce4faac9.png
# dataset_images/test\score2\f987dc20c52fabf88de2e2f84c5d7da6.png
# dataset_images/test\score0\f9bfaa0f3e244aaa4a0ce9df2497ad7c.png
# dataset_images/test\score5\f9e36d13598cf29965d05f572f43b8fd.png
# dataset_images/test\score5\fa21e03825c9cd872aaa90394631539f.png
# dataset_images/test\score5\fa416e251fb12b4c028bc735e5007266.png
# dataset_images/test\score4\fa83a2d6cdf98e9ebe62cecbf6247b28.png
# dataset_images/test\score1\fa8cfeca9803a5c718285690e4eb34fe.png
# dataset_images/test\score5\faa19f7be0cb717a6be6b667f315af88.png
# dataset_images/test\score3\faaf1f4411faa3ed4841b0bf44a66f44.png
# dataset_images/test\score3\fab7acc54e6d3d64585ac4b3d8fb26c5.png
# dataset_images/test\score4\facd17a01b1e90dd5a0915e007dfc96a.png
# dataset_images/test\score4\fafa20ed3182bb725b54606788600410.png
# dataset_images/test\score6\fb0e137fd84d235629916b61aedc5645.png
# dataset_images/test\score3\fb181b7ab541e5df5a1f1a65c889ff18.png
# dataset_images/test\score6\fb18d824e654968e0084f5ea629869cb.png
# dataset_images/test\score4\fb1a9ec8d76aee8bdc93c823caae185a.png
# dataset_images/test\score4\fb425891ddf88066f7793ce54db65421.png
# dataset_images/test\score3\fb598b6f723f6b22184638190a01caa1.png
# dataset_images/test\score2\fb641ae73245db25c980ed8015b06159.png
# dataset_images/test\score6\fb68a714defe0cd8931876903b24f0ac.png
# dataset_images/test\score5\fb6e4037dd3341351018ad3acf9f5d35.png
# dataset_images/test\score4\fb7d65d21c8b932b38d3da1f9929c2a8.png
# dataset_images/test\score4\fb83395ecf8181633f400e2e822a1b78.png
# dataset_images/test\score2\fb8b4b27dd82259e5a2bb60efa2544a7.png
# dataset_images/test\score5\fb96ac3e72053bbdf24301e420f051ea.png
# dataset_images/test\score4\fbad859fa99cd7b1b575819f96f95d56.png
# dataset_images/test\score6\fc06e3c216acc0b0cce724b8df78e937.png
# dataset_images/test\score5\fc15ceb8e04b3cce05a968b3d1dea044.png
# dataset_images/test\score4\fc292b41079a14c89779e29cadff167d.png
# dataset_images/test\score4\fc29f726831241f9255069728cda7ecf.png
# dataset_images/test\score4\fc495beb0224737cb32b4026b5cd14d1.png
# dataset_images/test\score6\fc5f274d77c03130ce7e0979deab3a8b.png
# dataset_images/test\score4\fc6050adafe9832b37bfe7cef4d5a1ee.png
# dataset_images/test\score3\fc6d00aa6fd54e3c6a7d4c6e564fb4d5.png
# dataset_images/test\score2\fc73763c01ba79dd6c03933cc5720085.png
# dataset_images/test\score3\fc749b373ff2d0fe54ce4f0632cb417b.png
# dataset_images/test\score2\fc91faf5e012a9a51d03e7823344b06c.png
# dataset_images/test\score4\fc9582e49b3f981b97fd5fc186e417ae.png
# dataset_images/test\score2\fca98adb802cc38bbe6c847505ffe018.png
# dataset_images/test\score5\fcebef7705bc881450b563c0531d3336.png
# dataset_images/test\score6\fcf8ff9008466442239d4e0e2d86a061.png
# dataset_images/test\score2\fd055895042fd939aabb55cb0d9f7af6.png
# dataset_images/test\score7\fd06e94b641665a05f164e92a2afe85c.png
# dataset_images/test\score2\fd07823265cc1db4e36b7edc128cb071.png
# dataset_images/test\score3\fd1268fc0cc8dc1490decdb34e092d23.png
# dataset_images/test\score5\fd1d8242ca4cf8cb77b376d178f9eaf2.png
# dataset_images/test\score3\fd342a9935d2e7e94feb0233eb33db9e.png
# dataset_images/test\score3\fd39bcb1334b9e8bc8f17b5a7967a390.png
# dataset_images/test\score5\fd52c0a10e14741cc83e2996e4520bdd.png
# dataset_images/test\score5\fd7a3cde52002f8b617f6faf3ffc64ca.png
# dataset_images/test\score3\fd7a8829b2eac5d2410fee1c2f44f22c.png
# dataset_images/test\score5\fd7cddffbda5723b05cd2d3b69f6ddf8.png
# dataset_images/test\score3\fdae1b934c78be837b400f943f6107ce.png
# dataset_images/test\score2\fdb89752af722a9885c377fdaba5e267.png
# dataset_images/test\score3\fdbe2ba76b6428090469f4a5a27b6b69.png
# dataset_images/test\score5\fddb622e9bf3db0932210d540dfa7638.png
# dataset_images/test\score1\fde764e8a2220eab40e4893dbf0676ad.png
# dataset_images/test\score2\fdf86bda1e251a6c6b51856c41b514a2.png
# dataset_images/test\score4\fe0431de469b83428cd8bfeb577a5dbe.png
# dataset_images/test\score4\fe04cb09571c7e90f9e18e38e3ef31d2.png
# dataset_images/test\score5\fe1dbe61363ddd5f9c093b3dc4ccc059.png
# dataset_images/test\score4\fe1ecb1d300b4dd7ee63294dd387ea0c.png
# dataset_images/test\score5\fe3ef2947f3c0f87840b313e6dcdd53d.png
# dataset_images/test\score1\fe595e956f6bf5d7bea77784f25d8400.png
# dataset_images/test\score3\fe852f6180a649e247bfc894ed69fecc.png
# dataset_images/test\score6\fea5b746943367770e1c51f6d2c16b0f.png
# dataset_images/test\score4\fee063dcc1820b55183aa05df8dd12fb.png
# dataset_images/test\score3\fef43912da771e804b2c87e19d9a686a.png
# dataset_images/test\score4\fef4a16b60b8c58df932c8485527e059.png
# dataset_images/test\score4\fefc8055937c0cd231d035bb1b3f7af7.png
# dataset_images/test\score3\fefeb040cba0ee17a68e9a02066eb37c.png
# dataset_images/test\score5\ff0dd89af6e8c411356a444c3b2f34dc.png
# dataset_images/test\score3\ff3d5c18aba6d779fafec66fce6db9a7.png
# dataset_images/test\score4\ff446f15c8edf160b08653e8fb79accb.png
# dataset_images/test\score3\ff746e5e2302d22ff251253539387f04.png
# dataset_images/test\score3\ff7f09b7a0c79b50f3bc009ee71516b3.png
# dataset_images/test\score5\ffa24106dd2dc46e0dbf233c171ad99a.png
# dataset_images/test\score5\ffa83a1e1e3298bbad505a5cf5f73244.png
# dataset_images/test\score4\ffb6bb88af295fc1f71e46ff14fb31c2.png
# dataset_images/test\score3\ffba6532d75a6649f8d2a6d1812fb65b.png
# dataset_images/test\score2\ffd16600bf35704a1141d9d8f6759287.png
# dataset_images/test\score6\fff12885730f7368defe870db782c81e.png
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[203], line 30
#      27     # move_to_class_folders(train_folder, class_mapping)
#      28     move_to_class_folders(test_folder, class_mapping)
# ---> 30 order_images_dataset_to_classes()
#
# Cell In[203], line 28, in order_images_dataset_to_classes(train_folder, test_folder, class_mapping)
#      25         shutil.move(src_path, dest_path)
#      27 # move_to_class_folders(train_folder, class_mapping)
# ---> 28 move_to_class_folders(test_folder, class_mapping)
#
# Cell In[203], line 20, in order_images_dataset_to_classes.<locals>.move_to_class_folders(source_folder, class_mapping)
#      18 src_path = os.path.join(source_folder, img)
#      19 labels_key = os.path.splitext(os.path.basename(src_path))[0]
# ---> 20 label = labels[labels_key]
#      21 class_folder = class_mapping[label]
#      23 dest_path = os.path.join(source_folder, class_folder, img)
#
# KeyError: 'score0'
